# %% [markdown]
# This is run by ResNet like architecture with first pooling layer adjustments

# %%
import numpy as np
import matplotlib.pyplot as plt

import sys
from pathlib import Path

#torch 
import torch
import torchvision as torchv
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from torch import Tensor
from torch.utils import data

from sklearn.model_selection import train_test_split

from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sn

# %%
#Metode for å hente data frå mappe
module_path = str(Path.cwd().parents[0].parents[0] / "methods")

if module_path not in sys.path:
    sys.path.append(module_path)

from dataloader import *
# from plotCreator import *

data_path0 = str(Path.cwd().parents[0].parents[0] / "data" / "BH_n4_M10_res50_15000_events.h5")
data_path1 = str(Path.cwd().parents[0].parents[0] / "data" / "PP13-Sphaleron-THR9-FRZ15-NB0-NSUBPALL_res50_15000_events.h5")

# %%
#Hente data og sette til array
bhArray = dataToArray(data_path0)
sphArray = dataToArray(data_path1)

# print(bhArray.shape)
# print(sphArray.shape)

# %%
#Kombinerer dataene for å kunne kjøre gjennom modellen på et samlet datasett
dataArray = np.concatenate((bhArray,sphArray),axis=0)

# %%
# Labeler tabelle med 1 og 0 (0 = svart hull, 1 = spahleron)
labelsArray = np.concatenate((np.zeros(np.shape(bhArray)[0]),np.ones(np.shape(sphArray)[0])),axis=0)

# %%
#Sjekke om device GPU er på
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("Running on the GPU")
else:
    device = torch.device("cpu")
    print("Running on the CPU")
# Out:
# Running on the GPU

# %%
#Split data 75% i train og 25% i test
trainData, testData, trainLabels, testLabels = train_test_split(dataArray, labelsArray, random_state=42)

# %%
#Transofrm from numpy array to torch
trainData = torch.from_numpy(trainData).permute(0,3,1,2)
testData = torch.from_numpy(testData).permute(0,3,1,2)
trainLabels = torch.from_numpy(trainLabels)
testLabels = torch.from_numpy(testLabels)

# %%
#Transformere numpy til tensor
train = torch.utils.data.TensorDataset(trainData, trainLabels)
test = torch.utils.data.TensorDataset(testData, testLabels)

# %%
#Transform data data to dataloader
trainLoader = DataLoader(train, shuffle=True, batch_size=50)
testLoader = DataLoader(test, shuffle=True, batch_size=50)

# %%
from torchsummary import summary
import nnmodel

model = nnmodel.VGGNet2(0.6).to(device)  # Move the model to the appropriate device

# Print the model summary, make sure to provide appropriate input size (3, 50, 50) for the 3-channel 50x50 images
summary(model, input_size=(3, 50, 50))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 50, 50]           1,792
#        BatchNorm2d-2           [-1, 64, 50, 50]             128
#               ReLU-3           [-1, 64, 50, 50]               0
#             Conv2d-4           [-1, 64, 50, 50]          36,928
#        BatchNorm2d-5           [-1, 64, 50, 50]             128
#               ReLU-6           [-1, 64, 50, 50]               0
#          MaxPool2d-7           [-1, 64, 25, 25]               0
#            Dropout-8           [-1, 64, 25, 25]               0
#             Conv2d-9          [-1, 128, 25, 25]          73,856
#       BatchNorm2d-10          [-1, 128, 25, 25]             256
#              ReLU-11          [-1, 128, 25, 25]               0
#            Conv2d-12          [-1, 128, 25, 25]         147,584
#       BatchNorm2d-13          [-1, 128, 25, 25]             256
#              ReLU-14          [-1, 128, 25, 25]               0
#            Conv2d-15          [-1, 128, 25, 25]         147,584
#       BatchNorm2d-16          [-1, 128, 25, 25]             256
#              ReLU-17          [-1, 128, 25, 25]               0
#         MaxPool2d-18          [-1, 128, 12, 12]               0
#              ReLU-74            [-1, 512, 6, 6]               0
#            Conv2d-75            [-1, 512, 6, 6]       2,359,808
#       BatchNorm2d-76            [-1, 512, 6, 6]           1,024
#              ReLU-77            [-1, 512, 6, 6]               0
#            Conv2d-78            [-1, 512, 6, 6]       2,359,808
#       BatchNorm2d-79            [-1, 512, 6, 6]           1,024
#              ReLU-80            [-1, 512, 6, 6]               0
#         MaxPool2d-81            [-1, 512, 3, 3]               0
#           Dropout-82            [-1, 512, 3, 3]               0
#            Conv2d-83           [-1, 64, 50, 50]           1,792
#       BatchNorm2d-84           [-1, 64, 50, 50]             128
#              ReLU-85           [-1, 64, 50, 50]               0
#            Conv2d-86           [-1, 64, 50, 50]          36,928
#       BatchNorm2d-87           [-1, 64, 50, 50]             128
#              ReLU-88           [-1, 64, 50, 50]               0
#         MaxPool2d-89           [-1, 64, 25, 25]               0
#           Dropout-90           [-1, 64, 25, 25]               0
#            Conv2d-91          [-1, 128, 25, 25]          73,856
#       BatchNorm2d-92          [-1, 128, 25, 25]             256
#              ReLU-93          [-1, 128, 25, 25]               0
#            Conv2d-94          [-1, 128, 25, 25]         147,584
#       BatchNorm2d-95          [-1, 128, 25, 25]             256
#              ReLU-96          [-1, 128, 25, 25]               0
#            Conv2d-97          [-1, 128, 25, 25]         147,584
#       BatchNorm2d-98          [-1, 128, 25, 25]             256
#              ReLU-99          [-1, 128, 25, 25]               0
#        MaxPool2d-100          [-1, 128, 12, 12]               0
#          Dropout-101          [-1, 128, 12, 12]               0
#           Conv2d-102          [-1, 256, 12, 12]         295,168
#      BatchNorm2d-103          [-1, 256, 12, 12]             512
#             ReLU-104          [-1, 256, 12, 12]               0
#           Conv2d-105          [-1, 256, 12, 12]         590,080
#      BatchNorm2d-106          [-1, 256, 12, 12]             512
#             ReLU-107          [-1, 256, 12, 12]               0
#           Conv2d-108          [-1, 256, 12, 12]         590,080
#      BatchNorm2d-109          [-1, 256, 12, 12]             512
#             ReLU-110          [-1, 256, 12, 12]               0
#        MaxPool2d-111            [-1, 256, 6, 6]               0
#          Dropout-112            [-1, 256, 6, 6]               0
#           Conv2d-113            [-1, 512, 6, 6]       1,180,160
#      BatchNorm2d-114            [-1, 512, 6, 6]           1,024
#             ReLU-115            [-1, 512, 6, 6]               0
#           Conv2d-116            [-1, 512, 6, 6]       2,359,808
#      BatchNorm2d-117            [-1, 512, 6, 6]           1,024
#             ReLU-118            [-1, 512, 6, 6]               0
#           Conv2d-119            [-1, 512, 6, 6]       2,359,808
#      BatchNorm2d-120            [-1, 512, 6, 6]           1,024
#             ReLU-121            [-1, 512, 6, 6]               0
#        MaxPool2d-122            [-1, 512, 3, 3]               0
#          Dropout-123            [-1, 512, 3, 3]               0
#           Conv2d-124           [-1, 64, 50, 50]           1,792
#      BatchNorm2d-125           [-1, 64, 50, 50]             128
#             ReLU-126           [-1, 64, 50, 50]               0
#           Conv2d-127           [-1, 64, 50, 50]          36,928
#      BatchNorm2d-128           [-1, 64, 50, 50]             128
#             ReLU-129           [-1, 64, 50, 50]               0
#        MaxPool2d-130           [-1, 64, 25, 25]               0
#          Dropout-131           [-1, 64, 25, 25]               0
#           Conv2d-132          [-1, 128, 25, 25]          73,856
#      BatchNorm2d-133          [-1, 128, 25, 25]             256
#             ReLU-134          [-1, 128, 25, 25]               0
#           Conv2d-135          [-1, 128, 25, 25]         147,584
#      BatchNorm2d-136          [-1, 128, 25, 25]             256
#             ReLU-137          [-1, 128, 25, 25]               0
#           Conv2d-138          [-1, 128, 25, 25]         147,584
#      BatchNorm2d-139          [-1, 128, 25, 25]             256
#             ReLU-140          [-1, 128, 25, 25]               0
#        MaxPool2d-141          [-1, 128, 12, 12]               0
#          Dropout-142          [-1, 128, 12, 12]               0
#           Conv2d-143          [-1, 256, 12, 12]         295,168
#      BatchNorm2d-144          [-1, 256, 12, 12]             512
#             ReLU-145          [-1, 256, 12, 12]               0
#           Conv2d-146          [-1, 256, 12, 12]         590,080
#      BatchNorm2d-147          [-1, 256, 12, 12]             512
#             ReLU-148          [-1, 256, 12, 12]               0
#           Conv2d-149          [-1, 256, 12, 12]         590,080
#      BatchNorm2d-150          [-1, 256, 12, 12]             512
#             ReLU-151          [-1, 256, 12, 12]               0
#        MaxPool2d-152            [-1, 256, 6, 6]               0
#          Dropout-153            [-1, 256, 6, 6]               0
#           Conv2d-154            [-1, 512, 6, 6]       1,180,160
#      BatchNorm2d-155            [-1, 512, 6, 6]           1,024
#             ReLU-156            [-1, 512, 6, 6]               0
#           Conv2d-157            [-1, 512, 6, 6]       2,359,808
#      BatchNorm2d-158            [-1, 512, 6, 6]           1,024
#             ReLU-159            [-1, 512, 6, 6]               0
#           Conv2d-160            [-1, 512, 6, 6]       2,359,808
#      BatchNorm2d-161            [-1, 512, 6, 6]           1,024
#             ReLU-162            [-1, 512, 6, 6]               0
#        MaxPool2d-163            [-1, 512, 3, 3]               0
#          Dropout-164            [-1, 512, 3, 3]               0
#           Linear-165                 [-1, 1024]       4,719,616
#             ReLU-166                 [-1, 1024]               0
#          Dropout-167                 [-1, 1024]               0
#           Linear-168                  [-1, 512]         524,800
#             ReLU-169                  [-1, 512]               0
#          Dropout-170                  [-1, 512]               0
#           Linear-171                  [-1, 256]         131,328
#             ReLU-172                  [-1, 256]               0
#          Dropout-173                  [-1, 256]               0
#           Linear-174                    [-1, 2]             514
# ================================================================
# Total params: 36,530,178
# Trainable params: 36,530,178
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.03
# Forward/backward pass size (MB): 70.91
# Params size (MB): 139.35
# Estimated Total Size (MB): 210.29
# ----------------------------------------------------------------

# %%
import trainer
# Set the learning rate and number of epochs
n_epochs = 10

# Create the model
model = nnmodel.VGGNet2(0.6).to(device)

# Set up the optimizer and criterion
optimizer = torch.optim.Adam(model.parameters())
criterion = nn.CrossEntropyLoss().to(device)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=3, verbose=True, factor=0.5)

# Train the model
trainer.train(model, trainLoader, testLoader, optimizer, criterion, n_epochs, scheduler = scheduler, early_stopping_patience = 10)
# Out:
# Epoch: 0/50
# Train Loss: 0.3162, Train Accuracy: 88.00%
# Test Loss: 0.2229, Test Accuracy: 91.36%
# Epoch: 1/50
# Train Loss: 0.2487, Train Accuracy: 90.93%
# Test Loss: 0.2525, Test Accuracy: 90.47%
# Epoch: 2/50
# Train Loss: 0.2376, Train Accuracy: 91.67%
# Test Loss: 0.1825, Test Accuracy: 93.03%
# Epoch: 3/50
# Train Loss: 0.2231, Train Accuracy: 91.96%
# Test Loss: 0.2005, Test Accuracy: 91.79%
# Epoch: 4/50
# Train Loss: 0.2169, Train Accuracy: 92.17%
# Test Loss: 0.1838, Test Accuracy: 93.52%
# Epoch: 5/50
# Train Loss: 0.2144, Train Accuracy: 92.00%
# Test Loss: 0.1898, Test Accuracy: 93.11%
# Epoch: 6/50
# Train Loss: 0.2058, Train Accuracy: 92.37%
# Test Loss: 0.2074, Test Accuracy: 92.16%
# Epoch 00007: reducing learning rate of group 0 to 5.0000e-04.
# Epoch: 7/50
# Train Loss: 0.1836, Train Accuracy: 93.28%
# Test Loss: 0.1945, Test Accuracy: 92.08%
# Epoch: 8/50
# Train Loss: 0.1809, Train Accuracy: 93.28%
# Test Loss: 0.2147, Test Accuracy: 92.12%
# Epoch: 9/50
# Train Loss: 0.1787, Train Accuracy: 93.52%
# Test Loss: 0.1701, Test Accuracy: 93.67%
# Epoch: 10/50
# Train Loss: 0.1690, Train Accuracy: 93.60%
# Test Loss: 0.1583, Test Accuracy: 94.16%
# Epoch: 11/50
# Train Loss: 0.1724, Train Accuracy: 93.56%
# Test Loss: 0.1582, Test Accuracy: 93.76%
# Epoch: 12/50
# Train Loss: 0.1663, Train Accuracy: 93.88%
# Test Loss: 0.1659, Test Accuracy: 93.61%
# Epoch: 13/50
# Train Loss: 0.1658, Train Accuracy: 93.90%
# Test Loss: 0.1757, Test Accuracy: 93.29%
# Epoch: 14/50
# Train Loss: 0.1624, Train Accuracy: 94.04%
# Test Loss: 0.1986, Test Accuracy: 91.88%
# Epoch: 15/50
# Train Loss: 0.1645, Train Accuracy: 93.96%
# Test Loss: 0.1722, Test Accuracy: 93.12%
# Epoch 00016: reducing learning rate of group 0 to 2.5000e-04.
# Epoch: 16/50
# Train Loss: 0.1521, Train Accuracy: 94.47%
# Test Loss: 0.1731, Test Accuracy: 93.39%
# Epoch: 17/50
# Train Loss: 0.1520, Train Accuracy: 94.52%
# Test Loss: 0.1832, Test Accuracy: 92.63%
# Epoch: 18/50
# Train Loss: 0.1467, Train Accuracy: 94.49%
# Test Loss: 0.1697, Test Accuracy: 93.69%
# Epoch: 19/50
# Train Loss: 0.1442, Train Accuracy: 94.64%
# Test Loss: 0.1696, Test Accuracy: 93.20%
# Epoch 00020: reducing learning rate of group 0 to 1.2500e-04.
# Epoch: 20/50
# Train Loss: 0.1435, Train Accuracy: 94.68%
# Test Loss: 0.1612, Test Accuracy: 93.95%
# Epoch: 21/50
# Train Loss: 0.1445, Train Accuracy: 94.79%
# Test Loss: 0.1621, Test Accuracy: 93.71%
# Early stopping at epoch 21
