# %% [markdown]
# ## Here is final code where we run the best modified CNN model with different data agumentation techniques as well as combined data augmentation to see if we introduce bias into classification

# %%
import numpy as np
import matplotlib.pyplot as plt
from torchsummary import summary

import sys
from pathlib import Path

#torch 
import torch
import torchvision as torchv
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from torch import Tensor
from torch.utils import data
from PIL import Image
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_fscore_support

import pandas as pd
import seaborn as sn

# %%
#Metode for å hente data frå mappe
module_path = str(Path.cwd().parents[0].parents[0] / "methods")

if module_path not in sys.path:
    sys.path.append(module_path)

from dataloader import *
# from plotCreator import *

data_path0 = str(Path.cwd().parents[0].parents[0] / "data" / "BH_n4_M10_res50_15000_events.h5")
data_path1 = str(Path.cwd().parents[0].parents[0] / "data" / "PP13-Sphaleron-THR9-FRZ15-NB0-NSUBPALL_res50_15000_events.h5")

# %%
#Hente data og sette til array
bhArray = dataToArray(data_path0)
sphArray = dataToArray(data_path1)

# %%
#Kombinerer dataene for å kunne kjøre gjennom modellen på et samlet datasett
dataArray = np.concatenate((bhArray,sphArray),axis=0)

# %%
# Label array where BH is 0 and Sphalerons are 1
labelsArray = np.concatenate((np.zeros(np.shape(bhArray)[0]),np.ones(np.shape(sphArray)[0])),axis=0)

# %%
#Check if device is running on GPU
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("Running on the GPU")
else:
    device = torch.device("cpu")
    print("Running on the CPU")
# Out:
# Running on the GPU

# %%
#Split data 75% into train and 25% into test
trainData, testData, trainLabels, testLabels = train_test_split(dataArray, labelsArray, random_state=42)

# %% [markdown]
# Data augmentation process where we flip horizontally, and rotate images by 180 degrees randomly thus increasing training set.
# As well as we siplace images top down on y axes
#
# Commented out part where we crop images in width which can potentially increase models precision

# %%
def random_shift_y(img, roll_axis):
    shift = torch.randint(low=0, high=list(img.shape)[roll_axis], size=(1, 1)).item()
    img = torch.roll(img, shift, roll_axis)
    return img

def augment_images(images):
    images = np.moveaxis(images, -1, 1)
    augmented_images = []
    for img in images:
        img = torch.from_numpy(img)
        
        img_flipped_horizontal = torch.flip(img, dims=[2])
        img_flipped_vertical = random_shift_y(img, roll_axis=1)
        img_rotated_180 = torch.rot90(img, 2, dims=[1, 2])

        augmented_images.extend(
            [img, img_flipped_horizontal, img_flipped_vertical, img_rotated_180]
        )
    return torch.stack(augmented_images)  # Use torch.stack instead of np.array

# Apply data augmentation only on the training set
augmented_trainData = augment_images(trainData)

# Repeat the labels for the training set to match the augmented dataset
trainLabels_repeated = np.repeat(trainLabels, 4)

# Convert the augmented training data and repeated labels to PyTorch tensors
trainLabels_repeated = torch.from_numpy(trainLabels_repeated)

# Create a TensorDataset from the augmented training data and repeated labels
train_augmented = torch.utils.data.TensorDataset(augmented_trainData, trainLabels_repeated)

# Create a DataLoader for the augmented training dataset with shuffle enabled and batch size of 50
trainLoader_augmented = DataLoader(train_augmented, shuffle=True, batch_size=50)

# Apply the same preprocessing step to the test set as the training set
testData_processed = np.moveaxis(testData, -1, 1)

# Create a TensorDataset for the test data
test = torch.utils.data.TensorDataset(torch.from_numpy(testData_processed), torch.from_numpy(testLabels))

# Create a DataLoader for the test data with shuffle and batch size
testLoader = DataLoader(test, shuffle=True, batch_size=50)

# %% [markdown]
# This code allows us to look on orignial data image as well as its augmented forms

# %%
def visualize_comparison(original_images, augmented_images, labels, title, augmentation_info=None):
    n_images = len(original_images)
    n_columns = 4
    n_rows = n_images

    augmented_types = ['Original', 'Flip Vertical', 'Displace up/down', 'Rotate 180']

    fig, axs = plt.subplots(n_rows, n_columns, figsize=(3 * n_columns, 3 * n_rows))
    fig.suptitle(title)

    for i in range(n_images):
        for j in range(n_columns):
            if j == 0:
                img = original_images[i]
            else:
                img = augmented_images[4 * i + j]

            if isinstance(img, np.ndarray):
                img_rgb = np.moveaxis(img, 0, -1) if img.shape[0] == 3 else img
            elif isinstance(img, torch.Tensor):
                img_rgb = np.moveaxis(img.numpy(), 0, -1)

            ax = axs[i, j]
            ax.imshow(img_rgb)
            ax.set_title(f"{augmented_types[j]} - Label: {'BH' if labels[i] == 1 else 'SPH'}") #Change labels such that if 1 Bh if 1 then Sph
            ax.axis('off')

    plt.show()

n_samples = 4
original_images = trainData[:n_samples]
original_labels = trainLabels[:n_samples]
augmented_images = augmented_trainData[:4 * n_samples]

visualize_comparison(original_images, augmented_images, original_labels, title="Original and Augmented Images")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# Here we make a call on nnmodel.py in methods fodler where all our models resign

# %%
import nnmodel

model = nnmodel.SymmetricNet2(0.5).to(device)  # Move the model to the appropriate device

# Print the model summary, make sure to provide appropriate input size (3, 50, 50) for the 3-channel 50x50 images
summary(model, (3, 50, 50))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 128, 48, 48]           3,584
#        BatchNorm2d-2          [-1, 128, 48, 48]             256
#             Conv2d-3          [-1, 128, 48, 48]           3,584
#        BatchNorm2d-4          [-1, 128, 48, 48]             256
#             Conv2d-5          [-1, 128, 48, 48]           3,584
#        BatchNorm2d-6          [-1, 128, 48, 48]             256
#  CircularAvgPool2d-7          [-1, 128, 25, 24]               0
#  CircularAvgPool2d-8          [-1, 128, 25, 24]               0
#  CircularAvgPool2d-9          [-1, 128, 25, 24]               0
#           Dropout-10          [-1, 128, 25, 24]               0
#            Conv2d-11          [-1, 256, 22, 21]         524,544
#       BatchNorm2d-12          [-1, 256, 22, 21]             512
#         AvgPool2d-13          [-1, 256, 11, 10]               0
#           Dropout-14          [-1, 256, 11, 10]               0
#            Conv2d-15            [-1, 512, 9, 8]       1,180,160
#       BatchNorm2d-16            [-1, 512, 9, 8]           1,024
#         AvgPool2d-17            [-1, 512, 4, 4]               0
#           Dropout-18            [-1, 512, 4, 4]               0
#            Conv2d-19           [-1, 1024, 4, 4]      13,108,224
#       BatchNorm2d-20           [-1, 1024, 4, 4]           2,048
#         AvgPool2d-21           [-1, 1024, 2, 2]               0
#           Dropout-22           [-1, 1024, 2, 2]               0
#            Linear-23                  [-1, 256]       1,048,832
#           Dropout-24                  [-1, 256]               0
#            Linear-25                    [-1, 2]             514
# ================================================================
# Total params: 15,877,378
# Trainable params: 15,877,378
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.03
# Forward/backward pass size (MB): 19.08
# Params size (MB): 60.57
# Estimated Total Size (MB): 79.68
# ----------------------------------------------------------------

# %% [markdown]
# This function allow us to plot all metrics

# %%
def plot_metrics(augmentation_types, all_metrics):
    num_types = len(augmentation_types)
    
    metric_names = list(all_metrics[0].keys())
    num_metrics = len(metric_names)

    plt.figure(figsize=(20, 20))
    
    plot_index = 1
    for metric_name in metric_names:
        plt.subplot(num_metrics//2, 2, plot_index)
        for i, augment_type in enumerate(augmentation_types):
            plt.plot(all_metrics[i][metric_name], label=f'{augment_type} {metric_name}')
        plt.legend()
        plt.xlabel('Epoch')
        plt.ylabel(metric_name)
        plt.title(f'{metric_name} with Different Augmentations')
        plot_index += 1

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Here we make a call on train method from methods folder file trainers.py where all training and testing happends as well as plotting of accuracy, loss, precision, recall etc.
#
# Few changes added scheduler and early stopping to prevent from overfitting with changing learning rate if test loss and accuracy doesnt improve.

# %% [markdown]
# Here we train data and get plot of different augmentation techniques

# %%
import trainerRet

def train_with_augmentations(augmentation_types, num_runs=5):
    all_metrics = []

    augmentation_types = ["Combined"] + augmentation_types

    for augment_type in augmentation_types:
        n_epochs = 15
        avg_metrics = {key: np.zeros_like(value) for key, value in (all_metrics[0].items() 
                                                                    if all_metrics else {'train_losses': np.zeros(n_epochs), 'train_accs': np.zeros(n_epochs), 
                                                                                         'test_losses': np.zeros(n_epochs), 'test_accs': np.zeros(n_epochs), 
                                                                                         'black_holes_accs': np.zeros(n_epochs), 'sphalerons_accs': np.zeros(n_epochs), 
                                                                                         'black_holes_precisions': np.zeros(n_epochs), 
                                                                                         'sphalerons_precisions': np.zeros(n_epochs), 
                                                                                         'black_holes_recalls': np.zeros(n_epochs), 
                                                                                         'sphalerons_recalls': np.zeros(n_epochs), 
                                                                                         'black_holes_f1_scores': np.zeros(n_epochs), 
                                                                                         'sphalerons_f1_scores': np.zeros(n_epochs)}.items())}


        for run in range(num_runs):
            print(f"\nTraining with {augment_type} augmentation - Run {run + 1}")

            if augment_type == "Combined":
                trainLoader_filtered = trainLoader_augmented
            else:
                # Filter the augmented training data based on the augmentation type
                filter_indices = list(range(0, len(augmented_trainData), 4))  # Original images are always included
                if augment_type != "None":
                    aug_type_index = augmentation_types.index(augment_type) - 1
                    filter_indices += list(range(aug_type_index + 1, len(augmented_trainData), 4))
                filtered_trainData = augmented_trainData[filter_indices]
                filtered_trainLabels = trainLabels_repeated[filter_indices]

                # Create a TensorDataset and DataLoader for the filtered training data
                train_filtered = torch.utils.data.TensorDataset(filtered_trainData, filtered_trainLabels)
                trainLoader_filtered = DataLoader(train_filtered, shuffle=True, batch_size=50)

            # Train the model with the filtered training data
            model = nnmodel.ConvModelFPL(0.5).to(device)
            optimizer = torch.optim.Adam(model.parameters())
            criterion = nn.CrossEntropyLoss().to(device)
            scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=3, verbose=True, factor=0.5)
            metrics = trainerRet.train(model, trainLoader_filtered, testLoader, optimizer, criterion, n_epochs=n_epochs, scheduler=scheduler)

            # Accumulate the metrics for averaging
            for key in avg_metrics.keys():
                avg_metrics[key] += np.array(metrics[key])

        # Average the metrics
        for key in avg_metrics.keys():
            avg_metrics[key] /= num_runs

        all_metrics.append(avg_metrics)

    plot_metrics(augmentation_types, all_metrics)

# Train and compare the model with different data augmentations
augmentation_types = ["None", "Flip Horizontal", "Random Shift Y", "Rotate 180"]
train_with_augmentations(augmentation_types)
# Out:
# Training with Combined augmentation - Run 1
# Epoch: 0/15
# Train Loss: 0.3903, Train Accuracy: 79.20%
# Test Loss: 0.2360, Test Accuracy: 91.72%
# Epoch: 1/15
# Train Loss: 0.3496, Train Accuracy: 81.07%
# Test Loss: 0.2037, Test Accuracy: 92.47%
# Epoch: 2/15
# Train Loss: 0.3320, Train Accuracy: 81.76%
# Test Loss: 0.2350, Test Accuracy: 91.32%
# Epoch: 3/15
# Train Loss: 0.3263, Train Accuracy: 82.09%
# Test Loss: 0.2190, Test Accuracy: 92.27%
# Epoch: 4/15
# Train Loss: 0.3192, Train Accuracy: 82.06%
# Test Loss: 0.1801, Test Accuracy: 93.44%
# Epoch: 5/15
# Train Loss: 0.3147, Train Accuracy: 82.48%
# Test Loss: 0.1857, Test Accuracy: 93.09%
# Epoch: 6/15
# Train Loss: 0.3090, Train Accuracy: 82.54%
# Test Loss: 0.1784, Test Accuracy: 93.97%
# Epoch: 7/15
# Train Loss: 0.3059, Train Accuracy: 82.76%
# Test Loss: 0.1797, Test Accuracy: 93.95%
# Epoch: 8/15
# Train Loss: 0.2995, Train Accuracy: 83.03%
# Test Loss: 0.2210, Test Accuracy: 89.83%
# Epoch: 9/15
# Train Loss: 0.2959, Train Accuracy: 83.19%
# Test Loss: 0.1675, Test Accuracy: 93.69%
# Epoch: 10/15
# Train Loss: 0.2919, Train Accuracy: 83.34%
# Test Loss: 0.1959, Test Accuracy: 91.71%
# Epoch: 11/15
# Train Loss: 0.2905, Train Accuracy: 83.21%
# Test Loss: 0.1845, Test Accuracy: 92.52%
# Epoch: 12/15
# Train Loss: 0.2848, Train Accuracy: 83.53%
# Test Loss: 0.1830, Test Accuracy: 92.77%
# Epoch: 13/15
# Train Loss: 0.2827, Train Accuracy: 83.57%
# Test Loss: 0.1880, Test Accuracy: 92.69%
# Epoch 00014: reducing learning rate of group 0 to 5.0000e-04.
# Epoch: 14/15
# Train Loss: 0.2668, Train Accuracy: 84.34%
# Test Loss: 0.1634, Test Accuracy: 94.11%
#
# Training with Combined augmentation - Run 2
# Epoch: 0/15
# Train Loss: 0.3946, Train Accuracy: 78.82%
# Test Loss: 0.2271, Test Accuracy: 90.73%
# Epoch: 1/15
# Train Loss: 0.3487, Train Accuracy: 81.12%
# Test Loss: 0.2087, Test Accuracy: 91.29%
# Epoch: 2/15
# Train Loss: 0.3365, Train Accuracy: 81.54%
# Test Loss: 0.3133, Test Accuracy: 87.04%
# Epoch: 3/15
# Train Loss: 0.3268, Train Accuracy: 81.95%
# Test Loss: 0.2024, Test Accuracy: 93.36%
# Epoch: 4/15
# Train Loss: 0.3209, Train Accuracy: 82.26%
# Test Loss: 0.1845, Test Accuracy: 93.67%
# Epoch: 5/15
# Train Loss: 0.3157, Train Accuracy: 82.25%
# Test Loss: 0.1926, Test Accuracy: 92.71%
# Epoch: 6/15
# Train Loss: 0.3143, Train Accuracy: 82.41%
# Test Loss: 0.1912, Test Accuracy: 92.43%
# Epoch: 7/15
# Train Loss: 0.3051, Train Accuracy: 82.66%
# Test Loss: 0.2022, Test Accuracy: 91.77%
# Epoch: 8/15
# Train Loss: 0.3015, Train Accuracy: 82.95%
# Test Loss: 0.1808, Test Accuracy: 93.19%
# Epoch: 9/15
# Train Loss: 0.3011, Train Accuracy: 82.94%
# Test Loss: 0.2258, Test Accuracy: 89.83%
# Epoch: 10/15
# Train Loss: 0.2945, Train Accuracy: 83.15%
# Test Loss: 0.1804, Test Accuracy: 92.61%
# Epoch: 11/15
# Train Loss: 0.2936, Train Accuracy: 83.19%
# Test Loss: 0.1923, Test Accuracy: 93.32%
# Epoch: 12/15
# Train Loss: 0.2865, Train Accuracy: 83.48%
# Test Loss: 0.2122, Test Accuracy: 91.23%
# Epoch: 13/15
# Train Loss: 0.2846, Train Accuracy: 83.42%
# Test Loss: 0.1761, Test Accuracy: 93.32%
# Epoch: 14/15
# Train Loss: 0.2809, Train Accuracy: 83.79%
# Test Loss: 0.1817, Test Accuracy: 92.69%
#
# Training with Combined augmentation - Run 3
# Epoch: 0/15
# Train Loss: 0.3893, Train Accuracy: 79.25%
# Test Loss: 0.2582, Test Accuracy: 88.20%
# Epoch: 1/15
# Train Loss: 0.3462, Train Accuracy: 81.29%
# Test Loss: 0.2082, Test Accuracy: 92.37%
# Epoch: 2/15
# Train Loss: 0.3338, Train Accuracy: 81.75%
# Test Loss: 0.2629, Test Accuracy: 88.49%
# Epoch: 3/15
# Train Loss: 0.3282, Train Accuracy: 81.96%
# Test Loss: 0.1896, Test Accuracy: 92.45%
# Epoch: 4/15
# Train Loss: 0.3192, Train Accuracy: 82.21%
# Test Loss: 0.2042, Test Accuracy: 92.03%
# Epoch: 5/15
# Train Loss: 0.3117, Train Accuracy: 82.50%
# Test Loss: 0.2231, Test Accuracy: 91.45%
# Epoch: 6/15
# Train Loss: 0.3094, Train Accuracy: 82.59%
# Test Loss: 0.1727, Test Accuracy: 93.29%
# Epoch: 7/15
# Train Loss: 0.3024, Train Accuracy: 82.91%
# Test Loss: 0.1662, Test Accuracy: 93.51%
# Epoch: 8/15
# Train Loss: 0.2971, Train Accuracy: 83.05%
# Test Loss: 0.1885, Test Accuracy: 92.97%
# Epoch: 9/15
# Train Loss: 0.2961, Train Accuracy: 83.10%
# Test Loss: 0.1924, Test Accuracy: 91.60%
# Epoch: 10/15
# Train Loss: 0.2918, Train Accuracy: 83.16%
# Test Loss: 0.1922, Test Accuracy: 92.45%
# Epoch: 11/15
# Train Loss: 0.2888, Train Accuracy: 83.35%
# Test Loss: 0.1726, Test Accuracy: 93.25%
# Epoch 00012: reducing learning rate of group 0 to 5.0000e-04.
# Epoch: 12/15
# Train Loss: 0.2733, Train Accuracy: 83.90%
# Test Loss: 0.1614, Test Accuracy: 93.79%
# Epoch: 13/15
# Train Loss: 0.2688, Train Accuracy: 84.07%
# Test Loss: 0.1804, Test Accuracy: 93.07%
# Epoch: 14/15
# Train Loss: 0.2639, Train Accuracy: 84.32%
# Test Loss: 0.1563, Test Accuracy: 94.09%
#
# Training with Combined augmentation - Run 4
# Epoch: 0/15
# Train Loss: 0.3938, Train Accuracy: 78.94%
# Test Loss: 0.2802, Test Accuracy: 89.52%
# Epoch: 1/15
# Train Loss: 0.3491, Train Accuracy: 81.12%
# Test Loss: 0.2798, Test Accuracy: 89.72%
# Epoch: 2/15
# Train Loss: 0.3379, Train Accuracy: 81.67%
# Test Loss: 0.2148, Test Accuracy: 91.32%
# Epoch: 3/15
# Train Loss: 0.3262, Train Accuracy: 81.87%
# Test Loss: 0.2104, Test Accuracy: 92.47%
# Epoch: 4/15
# Train Loss: 0.3242, Train Accuracy: 82.00%
# Test Loss: 0.2151, Test Accuracy: 92.28%
# Epoch: 5/15
# Train Loss: 0.3151, Train Accuracy: 82.46%
# Test Loss: 0.1922, Test Accuracy: 92.51%
# Epoch: 6/15
# Train Loss: 0.3099, Train Accuracy: 82.55%
# Test Loss: 0.2239, Test Accuracy: 90.33%
# Epoch: 7/15
# Train Loss: 0.3072, Train Accuracy: 82.85%
# Test Loss: 0.2021, Test Accuracy: 93.56%
# Epoch: 8/15
# Train Loss: 0.3048, Train Accuracy: 82.67%
# Test Loss: 0.1776, Test Accuracy: 92.71%
# Epoch: 9/15
# Train Loss: 0.2990, Train Accuracy: 83.21%
# Test Loss: 0.1738, Test Accuracy: 93.79%
# Epoch: 10/15
# Train Loss: 0.2966, Train Accuracy: 83.09%
# Test Loss: 0.1627, Test Accuracy: 93.88%
# Epoch: 11/15
# Train Loss: 0.2946, Train Accuracy: 83.20%
# Test Loss: 0.1679, Test Accuracy: 94.07%
# Epoch: 12/15
# Train Loss: 0.2901, Train Accuracy: 83.24%
# Test Loss: 0.1684, Test Accuracy: 94.21%
# Epoch: 13/15
# Train Loss: 0.2841, Train Accuracy: 83.47%
# Test Loss: 0.1743, Test Accuracy: 94.13%
# Epoch: 14/15
# Train Loss: 0.2844, Train Accuracy: 83.34%
# Test Loss: 0.1701, Test Accuracy: 92.97%
# Epoch 00015: reducing learning rate of group 0 to 5.0000e-04.
#
# Training with Combined augmentation - Run 5
# Epoch: 0/15
# Train Loss: 0.3881, Train Accuracy: 79.14%
# Test Loss: 0.2122, Test Accuracy: 91.55%
# Epoch: 1/15
# Train Loss: 0.3507, Train Accuracy: 81.08%
# Test Loss: 0.2637, Test Accuracy: 89.59%
# Epoch: 2/15
# Train Loss: 0.3371, Train Accuracy: 81.64%
# Test Loss: 0.2589, Test Accuracy: 90.95%
# Epoch: 3/15
# Train Loss: 0.3267, Train Accuracy: 81.95%
# Test Loss: 0.2032, Test Accuracy: 93.24%
# Epoch: 4/15
# Train Loss: 0.3231, Train Accuracy: 82.23%
# Test Loss: 0.1815, Test Accuracy: 93.60%
# Epoch: 5/15
# Train Loss: 0.3147, Train Accuracy: 82.25%
# Test Loss: 0.2209, Test Accuracy: 90.84%
# Epoch: 6/15
# Train Loss: 0.3135, Train Accuracy: 82.53%
# Test Loss: 0.2103, Test Accuracy: 90.89%
# Epoch: 7/15
# Train Loss: 0.3048, Train Accuracy: 82.65%
# Test Loss: 0.2099, Test Accuracy: 91.41%
# Epoch: 8/15
# Train Loss: 0.3046, Train Accuracy: 82.78%
# Test Loss: 0.2035, Test Accuracy: 91.65%
# Epoch 00009: reducing learning rate of group 0 to 5.0000e-04.
# Epoch: 9/15
# Train Loss: 0.2877, Train Accuracy: 83.38%
# Test Loss: 0.1689, Test Accuracy: 94.16%
# Epoch: 10/15
# Train Loss: 0.2817, Train Accuracy: 83.59%
# Test Loss: 0.1720, Test Accuracy: 93.49%
# Epoch: 11/15
# Train Loss: 0.2812, Train Accuracy: 83.59%
# Test Loss: 0.1699, Test Accuracy: 93.33%
# Epoch: 12/15
# Train Loss: 0.2748, Train Accuracy: 83.79%
# Test Loss: 0.1710, Test Accuracy: 93.81%
# Epoch: 13/15
# Train Loss: 0.2728, Train Accuracy: 84.06%
# Test Loss: 0.1623, Test Accuracy: 94.08%
# Epoch: 14/15
# Train Loss: 0.2708, Train Accuracy: 83.95%
# Test Loss: 0.1773, Test Accuracy: 93.28%
#
# Training with None augmentation - Run 1
# Epoch: 0/15
# Train Loss: 0.4482, Train Accuracy: 76.12%
# Test Loss: 0.3476, Test Accuracy: 84.95%
# Epoch: 1/15
# Train Loss: 0.3847, Train Accuracy: 79.44%
# Test Loss: 0.2357, Test Accuracy: 91.20%
# Epoch: 2/15
# Train Loss: 0.3714, Train Accuracy: 80.06%
# Test Loss: 0.2705, Test Accuracy: 88.49%
# Epoch: 3/15
# Train Loss: 0.3621, Train Accuracy: 80.38%
# Test Loss: 0.2343, Test Accuracy: 90.85%
# Epoch: 4/15
# Train Loss: 0.3493, Train Accuracy: 81.16%
# Test Loss: 0.2112, Test Accuracy: 91.67%
# Epoch: 5/15
# Train Loss: 0.3480, Train Accuracy: 80.93%
# Test Loss: 0.2049, Test Accuracy: 91.93%
# Epoch: 6/15
# Train Loss: 0.3427, Train Accuracy: 81.50%
# Test Loss: 0.2354, Test Accuracy: 90.36%
# Epoch: 7/15
# Train Loss: 0.3345, Train Accuracy: 81.69%
# Test Loss: 0.2767, Test Accuracy: 86.75%
# Epoch: 8/15
# Train Loss: 0.3368, Train Accuracy: 81.40%
# Test Loss: 0.2157, Test Accuracy: 91.89%
# Epoch: 9/15
# Train Loss: 0.3267, Train Accuracy: 81.53%
# Test Loss: 0.2331, Test Accuracy: 91.04%
# Epoch 00010: reducing learning rate of group 0 to 5.0000e-04.
# Epoch: 10/15
# Train Loss: 0.3148, Train Accuracy: 82.36%
# Test Loss: 0.1883, Test Accuracy: 93.19%
# Epoch: 11/15
# Train Loss: 0.3089, Train Accuracy: 82.08%
# Test Loss: 0.2097, Test Accuracy: 91.43%
# Epoch: 12/15
# Train Loss: 0.2987, Train Accuracy: 83.08%
# Test Loss: 0.1973, Test Accuracy: 93.27%
# Epoch: 13/15
# Train Loss: 0.2923, Train Accuracy: 83.27%
# Test Loss: 0.2569, Test Accuracy: 87.45%
# Epoch: 14/15
# Train Loss: 0.2931, Train Accuracy: 83.16%
# Test Loss: 0.1892, Test Accuracy: 92.88%
# Epoch 00015: reducing learning rate of group 0 to 2.5000e-04.
#
# Training with None augmentation - Run 2
# Epoch: 0/15
# Train Loss: 0.4464, Train Accuracy: 76.55%
# Test Loss: 0.2739, Test Accuracy: 89.33%
# Epoch: 1/15
# Train Loss: 0.3848, Train Accuracy: 79.47%
# Test Loss: 0.2724, Test Accuracy: 90.16%
# Epoch: 2/15
# Train Loss: 0.3687, Train Accuracy: 80.25%
# Test Loss: 0.2492, Test Accuracy: 89.85%
# Epoch: 3/15
# Train Loss: 0.3569, Train Accuracy: 80.75%
# Test Loss: 0.2180, Test Accuracy: 91.65%
# Epoch: 4/15
# Train Loss: 0.3462, Train Accuracy: 80.99%
# Test Loss: 0.2279, Test Accuracy: 91.57%
# Epoch: 5/15
# Train Loss: 0.3474, Train Accuracy: 81.12%
# Test Loss: 0.2524, Test Accuracy: 88.99%
# Epoch: 6/15
# Train Loss: 0.3428, Train Accuracy: 81.28%
# Test Loss: 0.2781, Test Accuracy: 88.33%
# Epoch: 7/15
# Train Loss: 0.3359, Train Accuracy: 81.60%
# Test Loss: 0.2244, Test Accuracy: 90.44%
# Epoch 00008: reducing learning rate of group 0 to 5.0000e-04.
# Epoch: 8/15
# Train Loss: 0.3182, Train Accuracy: 82.30%
# Test Loss: 0.2230, Test Accuracy: 92.65%
# Epoch: 9/15
# Train Loss: 0.3161, Train Accuracy: 82.56%
# Test Loss: 0.1921, Test Accuracy: 92.85%
# Epoch: 10/15
# Train Loss: 0.3035, Train Accuracy: 83.04%
# Test Loss: 0.1951, Test Accuracy: 92.89%
# Epoch: 11/15
# Train Loss: 0.3058, Train Accuracy: 82.80%
# Test Loss: 0.1857, Test Accuracy: 92.87%
# Epoch: 12/15
# Train Loss: 0.3025, Train Accuracy: 83.11%
# Test Loss: 0.3082, Test Accuracy: 87.76%
# Epoch: 13/15
# Train Loss: 0.3052, Train Accuracy: 82.38%
# Test Loss: 0.2015, Test Accuracy: 92.37%
# Epoch: 14/15
# Train Loss: 0.2976, Train Accuracy: 83.14%
# Test Loss: 0.1871, Test Accuracy: 92.56%
#
# Training with None augmentation - Run 3
# Epoch: 0/15
# Train Loss: 0.4464, Train Accuracy: 76.36%
# Test Loss: 0.2672, Test Accuracy: 90.00%
# Epoch: 1/15
# Train Loss: 0.3808, Train Accuracy: 79.42%
# Test Loss: 0.2585, Test Accuracy: 90.23%
# Epoch: 2/15
# Train Loss: 0.3642, Train Accuracy: 80.31%
# Test Loss: 0.2385, Test Accuracy: 90.17%
# Epoch: 3/15
# Train Loss: 0.3615, Train Accuracy: 80.44%
# Test Loss: 0.2258, Test Accuracy: 91.19%
# Epoch: 4/15
# Train Loss: 0.3488, Train Accuracy: 80.73%
# Test Loss: 0.2524, Test Accuracy: 90.79%
# Epoch: 5/15
# Train Loss: 0.3492, Train Accuracy: 81.39%
# Test Loss: 0.2452, Test Accuracy: 91.36%
# Epoch: 6/15
# Train Loss: 0.3411, Train Accuracy: 81.55%
# Test Loss: 0.2601, Test Accuracy: 88.01%
# Epoch: 7/15
# Train Loss: 0.3328, Train Accuracy: 81.79%
# Test Loss: 0.2007, Test Accuracy: 92.43%
# Epoch: 8/15
# Train Loss: 0.3256, Train Accuracy: 82.10%
# Test Loss: 0.2598, Test Accuracy: 90.48%
# Epoch: 9/15
# Train Loss: 0.3225, Train Accuracy: 82.03%
# Test Loss: 0.2180, Test Accuracy: 91.53%
# Epoch: 10/15
# Train Loss: 0.3267, Train Accuracy: 81.82%
# Test Loss: 0.2085, Test Accuracy: 92.13%
# Epoch: 11/15
# Train Loss: 0.3188, Train Accuracy: 82.12%
# Test Loss: 0.2170, Test Accuracy: 91.17%
# Epoch 00012: reducing learning rate of group 0 to 5.0000e-04.
# Epoch: 12/15
# Train Loss: 0.3036, Train Accuracy: 82.65%
# Test Loss: 0.2614, Test Accuracy: 90.71%
# Epoch: 13/15
# Train Loss: 0.2964, Train Accuracy: 83.40%
# Test Loss: 0.1943, Test Accuracy: 93.25%
# Epoch: 14/15
# Train Loss: 0.2887, Train Accuracy: 83.17%
# Test Loss: 0.1985, Test Accuracy: 92.17%
#
# Training with None augmentation - Run 4
# Epoch: 0/15
# Train Loss: 0.4446, Train Accuracy: 77.17%
# Test Loss: 0.2708, Test Accuracy: 89.63%
# Epoch: 1/15
# Train Loss: 0.3781, Train Accuracy: 79.92%
# Test Loss: 0.2262, Test Accuracy: 91.03%
# Epoch: 2/15
# Train Loss: 0.3691, Train Accuracy: 80.42%
# Test Loss: 0.2139, Test Accuracy: 91.51%
# Epoch: 3/15
# Train Loss: 0.3570, Train Accuracy: 80.68%
# Test Loss: 0.2348, Test Accuracy: 91.44%
# Epoch: 4/15
# Train Loss: 0.3443, Train Accuracy: 81.04%
# Test Loss: 0.2382, Test Accuracy: 89.15%
# Epoch: 5/15
# Train Loss: 0.3469, Train Accuracy: 80.98%
# Test Loss: 0.2187, Test Accuracy: 92.36%
# Epoch: 6/15
# Train Loss: 0.3319, Train Accuracy: 81.90%
# Test Loss: 0.2133, Test Accuracy: 91.71%
# Epoch: 7/15
# Train Loss: 0.3360, Train Accuracy: 81.49%
# Test Loss: 0.1984, Test Accuracy: 92.45%
# Epoch: 8/15
# Train Loss: 0.3241, Train Accuracy: 82.16%
# Test Loss: 0.2425, Test Accuracy: 92.71%
# Epoch: 9/15
# Train Loss: 0.3232, Train Accuracy: 82.01%
# Test Loss: 0.2136, Test Accuracy: 91.68%
# Epoch: 10/15
# Train Loss: 0.3201, Train Accuracy: 82.65%
# Test Loss: 0.1906, Test Accuracy: 92.24%
# Epoch: 11/15
# Train Loss: 0.3184, Train Accuracy: 82.33%
# Test Loss: 0.2401, Test Accuracy: 91.09%
# Epoch: 12/15
# Train Loss: 0.3132, Train Accuracy: 82.39%
# Test Loss: 0.2080, Test Accuracy: 91.59%
# Epoch: 13/15
# Train Loss: 0.3100, Train Accuracy: 82.29%
# Test Loss: 0.2670, Test Accuracy: 88.11%
# Epoch: 14/15
# Train Loss: 0.3054, Train Accuracy: 82.70%
# Test Loss: 0.2835, Test Accuracy: 88.96%
# Epoch 00015: reducing learning rate of group 0 to 5.0000e-04.
#
# Training with None augmentation - Run 5
# Epoch: 0/15
# Train Loss: 0.4431, Train Accuracy: 76.79%
# Test Loss: 0.2828, Test Accuracy: 88.04%
# Epoch: 1/15
# Train Loss: 0.3821, Train Accuracy: 79.57%
# Test Loss: 0.2699, Test Accuracy: 88.49%
# Epoch: 2/15
# Train Loss: 0.3666, Train Accuracy: 80.36%
# Test Loss: 0.2608, Test Accuracy: 89.56%
# Epoch: 3/15
# Train Loss: 0.3577, Train Accuracy: 80.87%
# Test Loss: 0.2979, Test Accuracy: 87.21%
# Epoch: 4/15
# Train Loss: 0.3503, Train Accuracy: 80.84%
# Test Loss: 0.2938, Test Accuracy: 87.95%
# Epoch: 5/15
# Train Loss: 0.3528, Train Accuracy: 80.71%
# Test Loss: 0.2558, Test Accuracy: 90.77%
# Epoch: 6/15
# Train Loss: 0.3398, Train Accuracy: 81.37%
# Test Loss: 0.2085, Test Accuracy: 91.85%
# Epoch: 7/15
# Train Loss: 0.3336, Train Accuracy: 81.70%
# Test Loss: 0.2330, Test Accuracy: 90.20%
# Epoch: 8/15
# Train Loss: 0.3274, Train Accuracy: 82.17%
# Test Loss: 0.2842, Test Accuracy: 87.68%
# Epoch: 9/15
# Train Loss: 0.3187, Train Accuracy: 82.39%
# Test Loss: 0.2076, Test Accuracy: 92.13%
# Epoch: 10/15
# Train Loss: 0.3211, Train Accuracy: 81.89%
# Test Loss: 0.2034, Test Accuracy: 92.25%
# Epoch: 11/15
# Train Loss: 0.3173, Train Accuracy: 82.11%
# Test Loss: 0.1898, Test Accuracy: 92.97%
# Epoch: 12/15
# Train Loss: 0.3149, Train Accuracy: 82.56%
# Test Loss: 0.2019, Test Accuracy: 92.01%
# Epoch: 13/15
# Train Loss: 0.3135, Train Accuracy: 82.81%
# Test Loss: 0.2275, Test Accuracy: 92.40%
# Epoch: 14/15
# Train Loss: 0.3105, Train Accuracy: 82.39%
# Test Loss: 0.2355, Test Accuracy: 91.76%
#
# Training with Flip Horizontal augmentation - Run 1
# Epoch: 0/15
# Train Loss: 0.4205, Train Accuracy: 77.75%
# Test Loss: 0.2224, Test Accuracy: 90.96%
# Epoch: 1/15
# Train Loss: 0.3645, Train Accuracy: 80.48%
# Test Loss: 0.2221, Test Accuracy: 91.37%
# Epoch: 2/15
# Train Loss: 0.3509, Train Accuracy: 80.97%
# Test Loss: 0.2256, Test Accuracy: 91.43%
# Epoch: 3/15
# Train Loss: 0.3384, Train Accuracy: 81.26%
# Test Loss: 0.2462, Test Accuracy: 90.79%
# Epoch: 4/15
# Train Loss: 0.3355, Train Accuracy: 81.80%
# Test Loss: 0.2095, Test Accuracy: 92.89%
# Epoch: 5/15
# Train Loss: 0.3281, Train Accuracy: 81.98%
# Test Loss: 0.2117, Test Accuracy: 91.51%
# Epoch: 6/15
# Train Loss: 0.3253, Train Accuracy: 82.13%
# Test Loss: 0.2081, Test Accuracy: 91.73%
# Epoch: 7/15
# Train Loss: 0.3179, Train Accuracy: 81.99%
# Test Loss: 0.1946, Test Accuracy: 93.07%
# Epoch: 8/15
# Train Loss: 0.3148, Train Accuracy: 82.41%
# Test Loss: 0.1976, Test Accuracy: 93.24%
# Epoch: 9/15
# Train Loss: 0.3084, Train Accuracy: 82.54%
# Test Loss: 0.2053, Test Accuracy: 91.12%
# Epoch: 10/15
# Train Loss: 0.3081, Train Accuracy: 82.42%
# Test Loss: 0.1947, Test Accuracy: 92.83%
# Epoch: 11/15
# Train Loss: 0.3052, Train Accuracy: 82.48%
# Test Loss: 0.1804, Test Accuracy: 93.05%
# Epoch: 12/15
# Train Loss: 0.2990, Train Accuracy: 82.82%
# Test Loss: 0.1939, Test Accuracy: 92.55%
# Epoch: 13/15
# Train Loss: 0.2977, Train Accuracy: 82.92%
# Test Loss: 0.1753, Test Accuracy: 93.79%
# Epoch: 14/15
# Train Loss: 0.2928, Train Accuracy: 83.14%
# Test Loss: 0.2184, Test Accuracy: 90.21%
#
# Training with Flip Horizontal augmentation - Run 2
# Epoch: 0/15
# Train Loss: 0.4212, Train Accuracy: 77.60%
# Test Loss: 0.3362, Test Accuracy: 84.60%
# Epoch: 1/15
# Train Loss: 0.3643, Train Accuracy: 80.43%
# Test Loss: 0.2119, Test Accuracy: 91.32%
# Epoch: 2/15
# Train Loss: 0.3525, Train Accuracy: 80.71%
# Test Loss: 0.2890, Test Accuracy: 90.00%
# Epoch: 3/15
# Train Loss: 0.3424, Train Accuracy: 81.48%
# Test Loss: 0.2069, Test Accuracy: 92.51%
# Epoch: 4/15
# Train Loss: 0.3332, Train Accuracy: 81.57%
# Test Loss: 0.2041, Test Accuracy: 92.85%
# Epoch: 5/15
# Train Loss: 0.3264, Train Accuracy: 82.05%
# Test Loss: 0.2100, Test Accuracy: 92.12%
# Epoch: 6/15
# Train Loss: 0.3272, Train Accuracy: 81.74%
# Test Loss: 0.1985, Test Accuracy: 92.20%
# Epoch: 7/15
# Train Loss: 0.3173, Train Accuracy: 82.52%
# Test Loss: 0.2204, Test Accuracy: 89.29%
# Epoch: 8/15
# Train Loss: 0.3175, Train Accuracy: 82.46%
# Test Loss: 0.1887, Test Accuracy: 92.92%
# Epoch: 9/15
# Train Loss: 0.3088, Train Accuracy: 82.72%
# Test Loss: 0.1832, Test Accuracy: 93.05%
# Epoch: 10/15
# Train Loss: 0.3068, Train Accuracy: 82.64%
# Test Loss: 0.2459, Test Accuracy: 88.91%
# Epoch: 11/15
# Train Loss: 0.3068, Train Accuracy: 82.68%
# Test Loss: 0.1972, Test Accuracy: 92.36%
# Epoch: 12/15
# Train Loss: 0.2996, Train Accuracy: 82.65%
# Test Loss: 0.2098, Test Accuracy: 90.43%
# Epoch: 13/15
# Train Loss: 0.2963, Train Accuracy: 83.18%
# Test Loss: 0.2016, Test Accuracy: 91.24%
# Epoch 00014: reducing learning rate of group 0 to 5.0000e-04.
# Epoch: 14/15
# Train Loss: 0.2829, Train Accuracy: 83.54%
# Test Loss: 0.1769, Test Accuracy: 93.52%
#
# Training with Flip Horizontal augmentation - Run 3
# Epoch: 0/15
# Train Loss: 0.4099, Train Accuracy: 78.46%
# Test Loss: 0.2314, Test Accuracy: 91.56%
# Epoch: 1/15
# Train Loss: 0.3597, Train Accuracy: 80.64%
# Test Loss: 0.2789, Test Accuracy: 88.43%
# Epoch: 2/15
# Train Loss: 0.3553, Train Accuracy: 80.89%
# Test Loss: 0.2175, Test Accuracy: 91.84%
# Epoch: 3/15
# Train Loss: 0.3413, Train Accuracy: 81.30%
# Test Loss: 0.1987, Test Accuracy: 92.08%
# Epoch: 4/15
# Train Loss: 0.3352, Train Accuracy: 81.76%
# Test Loss: 0.2269, Test Accuracy: 90.71%
# Epoch: 5/15
# Train Loss: 0.3278, Train Accuracy: 82.07%
# Test Loss: 0.2057, Test Accuracy: 92.56%
# Epoch: 6/15
# Train Loss: 0.3265, Train Accuracy: 82.07%
# Test Loss: 0.2013, Test Accuracy: 92.03%
# Epoch: 7/15
# Train Loss: 0.3196, Train Accuracy: 82.06%
# Test Loss: 0.2089, Test Accuracy: 91.88%
# Epoch 00008: reducing learning rate of group 0 to 5.0000e-04.
# Epoch: 8/15
# Train Loss: 0.2989, Train Accuracy: 82.88%
# Test Loss: 0.1836, Test Accuracy: 92.55%
# Epoch: 9/15
# Train Loss: 0.2935, Train Accuracy: 83.24%
# Test Loss: 0.1764, Test Accuracy: 93.40%
# Epoch: 10/15
# Train Loss: 0.2877, Train Accuracy: 83.49%
# Test Loss: 0.1913, Test Accuracy: 93.61%
# Epoch: 11/15
# Train Loss: 0.2857, Train Accuracy: 83.74%
# Test Loss: 0.1816, Test Accuracy: 92.81%
# Epoch: 12/15
# Train Loss: 0.2862, Train Accuracy: 83.32%
# Test Loss: 0.1786, Test Accuracy: 93.13%
# Epoch: 13/15
# Train Loss: 0.2769, Train Accuracy: 83.71%
# Test Loss: 0.1767, Test Accuracy: 92.57%
# Epoch 00014: reducing learning rate of group 0 to 2.5000e-04.
# Epoch: 14/15
# Train Loss: 0.2648, Train Accuracy: 84.18%
# Test Loss: 0.1748, Test Accuracy: 93.21%
#
# Training with Flip Horizontal augmentation - Run 4
# Epoch: 0/15
# Train Loss: 0.4141, Train Accuracy: 77.98%
# Test Loss: 0.3143, Test Accuracy: 89.01%
# Epoch: 1/15
# Train Loss: 0.3719, Train Accuracy: 80.00%
# Test Loss: 0.2318, Test Accuracy: 91.92%
# Epoch: 2/15
# Train Loss: 0.3556, Train Accuracy: 80.81%
# Test Loss: 0.2790, Test Accuracy: 89.81%
# Epoch: 3/15
# Train Loss: 0.3485, Train Accuracy: 80.96%
# Test Loss: 0.2414, Test Accuracy: 89.09%
# Epoch: 4/15
# Train Loss: 0.3330, Train Accuracy: 81.51%
# Test Loss: 0.2242, Test Accuracy: 91.80%
# Epoch: 5/15
# Train Loss: 0.3280, Train Accuracy: 82.04%
# Test Loss: 0.2312, Test Accuracy: 91.88%
# Epoch: 6/15
# Train Loss: 0.3213, Train Accuracy: 82.16%
# Test Loss: 0.1995, Test Accuracy: 92.67%
# Epoch: 7/15
# Train Loss: 0.3209, Train Accuracy: 82.31%
# Test Loss: 0.1841, Test Accuracy: 92.79%
# Epoch: 8/15
# Train Loss: 0.3198, Train Accuracy: 82.24%
# Test Loss: 0.1814, Test Accuracy: 93.45%
# Epoch: 9/15
# Train Loss: 0.3093, Train Accuracy: 82.79%
# Test Loss: 0.1927, Test Accuracy: 92.41%
# Epoch: 10/15
# Train Loss: 0.3036, Train Accuracy: 83.07%
# Test Loss: 0.1906, Test Accuracy: 92.76%
# Epoch: 11/15
# Train Loss: 0.3081, Train Accuracy: 82.83%
# Test Loss: 0.1826, Test Accuracy: 93.28%
# Epoch: 12/15
# Train Loss: 0.2967, Train Accuracy: 82.84%
# Test Loss: 0.1863, Test Accuracy: 92.99%
# Epoch 00013: reducing learning rate of group 0 to 5.0000e-04.
# Epoch: 13/15
# Train Loss: 0.2835, Train Accuracy: 83.55%
# Test Loss: 0.1758, Test Accuracy: 93.51%
# Epoch: 14/15
# Train Loss: 0.2795, Train Accuracy: 83.65%
# Test Loss: 0.1780, Test Accuracy: 93.17%
#
# Training with Flip Horizontal augmentation - Run 5
# Epoch: 0/15
# Train Loss: 0.4118, Train Accuracy: 77.86%
# Test Loss: 0.2261, Test Accuracy: 91.21%
# Epoch: 1/15
# Train Loss: 0.3628, Train Accuracy: 80.50%
# Test Loss: 0.2455, Test Accuracy: 90.27%
# Epoch: 2/15
# Train Loss: 0.3507, Train Accuracy: 80.87%
# Test Loss: 0.2022, Test Accuracy: 91.99%
# Epoch: 3/15
# Train Loss: 0.3414, Train Accuracy: 81.63%
# Test Loss: 0.2467, Test Accuracy: 89.39%
# Epoch: 4/15
# Train Loss: 0.3353, Train Accuracy: 81.58%
# Test Loss: 0.2603, Test Accuracy: 90.60%
# Epoch: 5/15
# Train Loss: 0.3254, Train Accuracy: 81.74%
# Test Loss: 0.2133, Test Accuracy: 91.88%
# Epoch: 6/15
# Train Loss: 0.3258, Train Accuracy: 82.09%
# Test Loss: 0.1894, Test Accuracy: 92.59%
# Epoch: 7/15
# Train Loss: 0.3153, Train Accuracy: 82.48%
# Test Loss: 0.2024, Test Accuracy: 91.45%
# Epoch: 8/15
# Train Loss: 0.3118, Train Accuracy: 82.44%
# Test Loss: 0.2014, Test Accuracy: 92.72%
# Epoch: 9/15
# Train Loss: 0.3060, Train Accuracy: 82.84%
# Test Loss: 0.1907, Test Accuracy: 92.68%
# Epoch: 10/15
# Train Loss: 0.3034, Train Accuracy: 82.59%
# Test Loss: 0.2061, Test Accuracy: 92.87%
# Epoch 00011: reducing learning rate of group 0 to 5.0000e-04.
# Epoch: 11/15
# Train Loss: 0.2906, Train Accuracy: 83.14%
# Test Loss: 0.1800, Test Accuracy: 92.75%
# Epoch: 12/15
# Train Loss: 0.2863, Train Accuracy: 83.39%
# Test Loss: 0.1802, Test Accuracy: 93.19%
# Epoch: 13/15
# Train Loss: 0.2787, Train Accuracy: 83.40%
# Test Loss: 0.1941, Test Accuracy: 91.79%
# Epoch: 14/15
# Train Loss: 0.2747, Train Accuracy: 83.81%
# Test Loss: 0.1785, Test Accuracy: 93.37%
#
# Training with Random Shift Y augmentation - Run 1
# Epoch: 0/15
# Train Loss: 0.4161, Train Accuracy: 78.10%
# Test Loss: 0.2380, Test Accuracy: 89.71%
# Epoch: 1/15
# Train Loss: 0.3666, Train Accuracy: 80.33%
# Test Loss: 0.2633, Test Accuracy: 88.45%
# Epoch: 2/15
# Train Loss: 0.3544, Train Accuracy: 80.63%
# Test Loss: 0.2096, Test Accuracy: 91.93%
# Epoch: 3/15
# Train Loss: 0.3487, Train Accuracy: 81.20%
# Test Loss: 0.2085, Test Accuracy: 92.41%
# Epoch: 4/15
# Train Loss: 0.3384, Train Accuracy: 81.74%
# Test Loss: 0.2038, Test Accuracy: 93.11%
# Epoch: 5/15
# Train Loss: 0.3321, Train Accuracy: 81.93%
# Test Loss: 0.1835, Test Accuracy: 92.79%
# Epoch: 6/15
# Train Loss: 0.3276, Train Accuracy: 81.78%
# Test Loss: 0.2060, Test Accuracy: 91.33%
# Epoch: 7/15
# Train Loss: 0.3237, Train Accuracy: 82.09%
# Test Loss: 0.2332, Test Accuracy: 91.47%
# Epoch: 8/15
# Train Loss: 0.3182, Train Accuracy: 82.46%
# Test Loss: 0.1989, Test Accuracy: 92.95%
# Epoch: 9/15
# Train Loss: 0.3172, Train Accuracy: 82.18%
# Test Loss: 0.2076, Test Accuracy: 92.87%
# Epoch 00010: reducing learning rate of group 0 to 5.0000e-04.
# Epoch: 10/15
# Train Loss: 0.3001, Train Accuracy: 83.05%
# Test Loss: 0.1840, Test Accuracy: 92.83%
# Epoch: 11/15
# Train Loss: 0.2916, Train Accuracy: 83.51%
# Test Loss: 0.1747, Test Accuracy: 93.03%
# Epoch: 12/15
# Train Loss: 0.2907, Train Accuracy: 83.21%
# Test Loss: 0.1774, Test Accuracy: 93.27%
# Epoch: 13/15
# Train Loss: 0.2887, Train Accuracy: 83.46%
# Test Loss: 0.2001, Test Accuracy: 93.05%
# Epoch: 14/15
# Train Loss: 0.2867, Train Accuracy: 83.42%
# Test Loss: 0.2023, Test Accuracy: 91.49%
#
# Training with Random Shift Y augmentation - Run 2
# Epoch: 0/15
# Train Loss: 0.4179, Train Accuracy: 77.75%
# Test Loss: 0.2962, Test Accuracy: 87.69%
# Epoch: 1/15
# Train Loss: 0.3671, Train Accuracy: 80.27%
# Test Loss: 0.2854, Test Accuracy: 89.33%
# Epoch: 2/15
# Train Loss: 0.3530, Train Accuracy: 80.80%
# Test Loss: 0.2670, Test Accuracy: 91.67%
# Epoch: 3/15
# Train Loss: 0.3454, Train Accuracy: 81.45%
# Test Loss: 0.2206, Test Accuracy: 92.68%
# Epoch: 4/15
# Train Loss: 0.3369, Train Accuracy: 81.36%
# Test Loss: 0.1999, Test Accuracy: 92.89%
# Epoch: 5/15
# Train Loss: 0.3330, Train Accuracy: 81.76%
# Test Loss: 0.2474, Test Accuracy: 91.29%
# Epoch: 6/15
# Train Loss: 0.3286, Train Accuracy: 81.66%
# Test Loss: 0.2012, Test Accuracy: 92.80%
# Epoch: 7/15
# Train Loss: 0.3246, Train Accuracy: 82.08%
# Test Loss: 0.2075, Test Accuracy: 92.03%
# Epoch: 8/15
# Train Loss: 0.3185, Train Accuracy: 82.26%
# Test Loss: 0.2211, Test Accuracy: 90.47%
# Epoch 00009: reducing learning rate of group 0 to 5.0000e-04.
# Epoch: 9/15
# Train Loss: 0.3064, Train Accuracy: 82.57%
# Test Loss: 0.2292, Test Accuracy: 89.52%
# Epoch: 10/15
# Train Loss: 0.3016, Train Accuracy: 82.98%
# Test Loss: 0.1742, Test Accuracy: 93.57%
# Epoch: 11/15
# Train Loss: 0.2979, Train Accuracy: 83.19%
# Test Loss: 0.1926, Test Accuracy: 93.37%
# Epoch: 12/15
# Train Loss: 0.2952, Train Accuracy: 83.28%
# Test Loss: 0.1734, Test Accuracy: 92.67%
# Epoch: 13/15
# Train Loss: 0.2901, Train Accuracy: 83.19%
# Test Loss: 0.1824, Test Accuracy: 93.84%
# Epoch: 14/15
# Train Loss: 0.2881, Train Accuracy: 83.29%
# Test Loss: 0.1702, Test Accuracy: 94.08%
#
# Training with Random Shift Y augmentation - Run 3
# Epoch: 0/15
# Train Loss: 0.4175, Train Accuracy: 78.12%
# Test Loss: 0.3594, Test Accuracy: 84.57%
# Epoch: 1/15
# Train Loss: 0.3656, Train Accuracy: 80.25%
# Test Loss: 0.3194, Test Accuracy: 84.19%
# Epoch: 2/15
# Train Loss: 0.3512, Train Accuracy: 81.22%
# Test Loss: 0.2371, Test Accuracy: 92.01%
# Epoch: 3/15
# Train Loss: 0.3450, Train Accuracy: 81.37%
# Test Loss: 0.2320, Test Accuracy: 92.79%
# Epoch: 4/15
# Train Loss: 0.3375, Train Accuracy: 81.56%
# Test Loss: 0.2243, Test Accuracy: 91.77%
# Epoch: 5/15
# Train Loss: 0.3324, Train Accuracy: 81.86%
# Test Loss: 0.3117, Test Accuracy: 89.24%
# Epoch: 6/15
# Train Loss: 0.3278, Train Accuracy: 82.04%
# Test Loss: 0.2273, Test Accuracy: 92.43%
# Epoch: 7/15
# Train Loss: 0.3210, Train Accuracy: 81.89%
# Test Loss: 0.2015, Test Accuracy: 92.96%
# Epoch: 8/15
# Train Loss: 0.3197, Train Accuracy: 82.41%
# Test Loss: 0.2181, Test Accuracy: 92.61%
# Epoch: 9/15
# Train Loss: 0.3149, Train Accuracy: 82.44%
# Test Loss: 0.2204, Test Accuracy: 89.59%
# Epoch: 10/15
# Train Loss: 0.3155, Train Accuracy: 82.30%
# Test Loss: 0.1756, Test Accuracy: 93.36%
# Epoch: 11/15
# Train Loss: 0.3158, Train Accuracy: 82.63%
# Test Loss: 0.2498, Test Accuracy: 87.99%
# Epoch: 12/15
# Train Loss: 0.3055, Train Accuracy: 82.85%
# Test Loss: 0.2490, Test Accuracy: 91.05%
# Epoch: 13/15
# Train Loss: 0.3039, Train Accuracy: 82.82%
# Test Loss: 0.1880, Test Accuracy: 93.36%
# Epoch: 14/15
# Train Loss: 0.3011, Train Accuracy: 82.85%
# Test Loss: 0.1999, Test Accuracy: 91.28%
# Epoch 00015: reducing learning rate of group 0 to 5.0000e-04.
#
# Training with Random Shift Y augmentation - Run 4
# Epoch: 0/15
# Train Loss: 0.4136, Train Accuracy: 78.01%
# Test Loss: 0.2715, Test Accuracy: 89.73%
# Epoch: 1/15
# Train Loss: 0.3664, Train Accuracy: 80.23%
# Test Loss: 0.2299, Test Accuracy: 90.48%
# Epoch: 2/15
# Train Loss: 0.3561, Train Accuracy: 80.85%
# Test Loss: 0.2239, Test Accuracy: 91.87%
# Epoch: 3/15
# Train Loss: 0.3482, Train Accuracy: 80.98%
# Test Loss: 0.2415, Test Accuracy: 91.27%
# Epoch: 4/15
# Train Loss: 0.3428, Train Accuracy: 81.28%
# Test Loss: 0.1997, Test Accuracy: 92.39%
# Epoch: 5/15
# Train Loss: 0.3297, Train Accuracy: 82.04%
# Test Loss: 0.2586, Test Accuracy: 89.93%
# Epoch: 6/15
# Train Loss: 0.3303, Train Accuracy: 81.61%
# Test Loss: 0.1998, Test Accuracy: 92.85%
# Epoch: 7/15
# Train Loss: 0.3247, Train Accuracy: 81.89%
# Test Loss: 0.1841, Test Accuracy: 93.51%
# Epoch: 8/15
# Train Loss: 0.3168, Train Accuracy: 82.58%
# Test Loss: 0.1841, Test Accuracy: 92.76%
# Epoch: 9/15
# Train Loss: 0.3177, Train Accuracy: 82.23%
# Test Loss: 0.2032, Test Accuracy: 92.59%
# Epoch: 10/15
# Train Loss: 0.3146, Train Accuracy: 82.44%
# Test Loss: 0.1774, Test Accuracy: 93.44%
# Epoch: 11/15
# Train Loss: 0.3078, Train Accuracy: 82.60%
# Test Loss: 0.2098, Test Accuracy: 92.07%
# Epoch: 12/15
# Train Loss: 0.3085, Train Accuracy: 82.62%
# Test Loss: 0.1879, Test Accuracy: 91.83%
# Epoch: 13/15
# Train Loss: 0.3065, Train Accuracy: 82.68%
# Test Loss: 0.1758, Test Accuracy: 94.00%
# Epoch: 14/15
# Train Loss: 0.2993, Train Accuracy: 82.92%
# Test Loss: 0.1761, Test Accuracy: 92.95%
#
# Training with Random Shift Y augmentation - Run 5
# Epoch: 0/15
# Train Loss: 0.4219, Train Accuracy: 77.69%
# Test Loss: 0.3132, Test Accuracy: 85.57%
# Epoch: 1/15
# Train Loss: 0.3638, Train Accuracy: 80.36%
# Test Loss: 0.2346, Test Accuracy: 90.56%
# Epoch: 2/15
# Train Loss: 0.3564, Train Accuracy: 81.02%
# Test Loss: 0.2043, Test Accuracy: 92.19%
# Epoch: 3/15
# Train Loss: 0.3447, Train Accuracy: 81.04%
# Test Loss: 0.2042, Test Accuracy: 91.97%
# Epoch: 4/15
# Train Loss: 0.3397, Train Accuracy: 81.67%
# Test Loss: 0.2063, Test Accuracy: 92.57%
# Epoch: 5/15
# Train Loss: 0.3361, Train Accuracy: 81.58%
# Test Loss: 0.2193, Test Accuracy: 92.57%
# Epoch: 6/15
# Train Loss: 0.3226, Train Accuracy: 82.05%
# Test Loss: 0.1953, Test Accuracy: 92.53%
# Epoch: 7/15
# Train Loss: 0.3217, Train Accuracy: 82.08%
# Test Loss: 0.2134, Test Accuracy: 92.03%
# Epoch: 8/15
# Train Loss: 0.3191, Train Accuracy: 82.15%
# Test Loss: 0.2757, Test Accuracy: 87.44%
# Epoch: 9/15
# Train Loss: 0.3161, Train Accuracy: 82.20%
# Test Loss: 0.2111, Test Accuracy: 93.53%
# Epoch: 10/15
# Train Loss: 0.3094, Train Accuracy: 82.63%
# Test Loss: 0.1823, Test Accuracy: 93.33%
# Epoch: 11/15
# Train Loss: 0.3097, Train Accuracy: 82.64%
# Test Loss: 0.1924, Test Accuracy: 92.88%
# Epoch: 12/15
# Train Loss: 0.3067, Train Accuracy: 82.82%
# Test Loss: 0.1941, Test Accuracy: 92.59%
# Epoch: 13/15
# Train Loss: 0.3064, Train Accuracy: 82.83%
# Test Loss: 0.2112, Test Accuracy: 92.09%
# Epoch: 14/15
# Train Loss: 0.3016, Train Accuracy: 83.04%
# Test Loss: 0.1723, Test Accuracy: 93.61%
#
# Training with Rotate 180 augmentation - Run 1
# Epoch: 0/15
# Train Loss: 0.4121, Train Accuracy: 78.20%
# Test Loss: 0.3536, Test Accuracy: 85.16%
# Epoch: 1/15
# Train Loss: 0.3653, Train Accuracy: 80.38%
# Test Loss: 0.2335, Test Accuracy: 90.95%
# Epoch: 2/15
# Train Loss: 0.3442, Train Accuracy: 81.06%
# Test Loss: 0.2429, Test Accuracy: 91.72%
# Epoch: 3/15
# Train Loss: 0.3364, Train Accuracy: 81.49%
# Test Loss: 0.2105, Test Accuracy: 92.16%
# Epoch: 4/15
# Train Loss: 0.3267, Train Accuracy: 81.97%
# Test Loss: 0.2209, Test Accuracy: 92.23%
# Epoch: 5/15
# Train Loss: 0.3253, Train Accuracy: 81.65%
# Test Loss: 0.1892, Test Accuracy: 92.67%
# Epoch: 6/15
# Train Loss: 0.3172, Train Accuracy: 82.19%
# Test Loss: 0.2530, Test Accuracy: 89.60%
# Epoch: 7/15
# Train Loss: 0.3098, Train Accuracy: 82.37%
# Test Loss: 0.1892, Test Accuracy: 92.85%
# Epoch: 8/15
# Train Loss: 0.3003, Train Accuracy: 83.05%
# Test Loss: 0.1953, Test Accuracy: 91.73%
# Epoch: 9/15
# Train Loss: 0.2947, Train Accuracy: 83.03%
# Test Loss: 0.2518, Test Accuracy: 89.13%
# Epoch 00010: reducing learning rate of group 0 to 5.0000e-04.
# Epoch: 10/15
# Train Loss: 0.2747, Train Accuracy: 83.89%
# Test Loss: 0.1762, Test Accuracy: 93.44%
# Epoch: 11/15
# Train Loss: 0.2637, Train Accuracy: 84.11%
# Test Loss: 0.2129, Test Accuracy: 92.24%
# Epoch: 12/15
# Train Loss: 0.2586, Train Accuracy: 84.24%
# Test Loss: 0.2646, Test Accuracy: 91.17%
# Epoch: 13/15
# Train Loss: 0.2487, Train Accuracy: 84.91%
# Test Loss: 0.2118, Test Accuracy: 92.87%
# Epoch: 14/15
# Train Loss: 0.2431, Train Accuracy: 85.02%
# Test Loss: 0.1940, Test Accuracy: 93.15%
# Epoch 00015: reducing learning rate of group 0 to 2.5000e-04.
#
# Training with Rotate 180 augmentation - Run 2
# Epoch: 0/15
# Train Loss: 0.4145, Train Accuracy: 77.95%
# Test Loss: 0.2488, Test Accuracy: 90.77%
# Epoch: 1/15
# Train Loss: 0.3623, Train Accuracy: 80.58%
# Test Loss: 0.2223, Test Accuracy: 91.48%
# Epoch: 2/15
# Train Loss: 0.3507, Train Accuracy: 81.15%
# Test Loss: 0.2142, Test Accuracy: 92.41%
# Epoch: 3/15
# Train Loss: 0.3416, Train Accuracy: 80.99%
# Test Loss: 0.2142, Test Accuracy: 91.17%
# Epoch: 4/15
# Train Loss: 0.3285, Train Accuracy: 82.01%
# Test Loss: 0.2273, Test Accuracy: 92.61%
# Epoch: 5/15
# Train Loss: 0.3211, Train Accuracy: 81.91%
# Test Loss: 0.2307, Test Accuracy: 90.01%
# Epoch: 6/15
# Train Loss: 0.3144, Train Accuracy: 82.21%
# Test Loss: 0.2078, Test Accuracy: 91.36%
# Epoch: 7/15
# Train Loss: 0.3081, Train Accuracy: 82.60%
# Test Loss: 0.2342, Test Accuracy: 89.60%
# Epoch: 8/15
# Train Loss: 0.3017, Train Accuracy: 82.49%
# Test Loss: 0.1964, Test Accuracy: 92.43%
# Epoch: 9/15
# Train Loss: 0.2955, Train Accuracy: 83.08%
# Test Loss: 0.1866, Test Accuracy: 92.83%
# Epoch: 10/15
# Train Loss: 0.2871, Train Accuracy: 83.32%
# Test Loss: 0.1815, Test Accuracy: 92.87%
# Epoch: 11/15
# Train Loss: 0.2843, Train Accuracy: 83.57%
# Test Loss: 0.2089, Test Accuracy: 91.65%
# Epoch: 12/15
# Train Loss: 0.2733, Train Accuracy: 83.98%
# Test Loss: 0.2048, Test Accuracy: 92.12%
# Epoch: 13/15
# Train Loss: 0.2657, Train Accuracy: 84.24%
# Test Loss: 0.1982, Test Accuracy: 92.68%
# Epoch: 14/15
# Train Loss: 0.2597, Train Accuracy: 84.26%
# Test Loss: 0.1976, Test Accuracy: 93.00%
# Epoch 00015: reducing learning rate of group 0 to 5.0000e-04.
#
# Training with Rotate 180 augmentation - Run 3
# Epoch: 0/15
# Train Loss: 0.4148, Train Accuracy: 78.17%
# Test Loss: 0.3003, Test Accuracy: 87.79%
# Epoch: 1/15
# Train Loss: 0.3589, Train Accuracy: 80.97%
# Test Loss: 0.3202, Test Accuracy: 84.67%
# Epoch: 2/15
# Train Loss: 0.3436, Train Accuracy: 81.18%
# Test Loss: 0.2196, Test Accuracy: 91.69%
# Epoch: 3/15
# Train Loss: 0.3364, Train Accuracy: 81.53%
# Test Loss: 0.2243, Test Accuracy: 90.68%
# Epoch: 4/15
# Train Loss: 0.3295, Train Accuracy: 81.61%
# Test Loss: 0.3861, Test Accuracy: 81.76%
# Epoch: 5/15
# Train Loss: 0.3174, Train Accuracy: 82.49%
# Test Loss: 0.1955, Test Accuracy: 93.03%
# Epoch: 6/15
# Train Loss: 0.3113, Train Accuracy: 82.41%
# Test Loss: 0.2853, Test Accuracy: 86.83%
# Epoch: 7/15
# Train Loss: 0.3058, Train Accuracy: 82.75%
# Test Loss: 0.2065, Test Accuracy: 91.63%
# Epoch: 8/15
# Train Loss: 0.2998, Train Accuracy: 82.98%
# Test Loss: 0.2040, Test Accuracy: 92.67%
# Epoch: 9/15
# Train Loss: 0.2931, Train Accuracy: 83.30%
# Test Loss: 0.1809, Test Accuracy: 93.16%
# Epoch: 10/15
# Train Loss: 0.2863, Train Accuracy: 83.38%
# Test Loss: 0.2749, Test Accuracy: 87.76%
# Epoch: 11/15
# Train Loss: 0.2828, Train Accuracy: 83.51%
# Test Loss: 0.1853, Test Accuracy: 93.27%
# Epoch: 12/15
# Train Loss: 0.2740, Train Accuracy: 83.86%
# Test Loss: 0.1834, Test Accuracy: 92.68%
# Epoch: 13/15
# Train Loss: 0.2648, Train Accuracy: 84.04%
# Test Loss: 0.2101, Test Accuracy: 92.29%
# Epoch 00014: reducing learning rate of group 0 to 5.0000e-04.
# Epoch: 14/15
# Train Loss: 0.2406, Train Accuracy: 84.90%
# Test Loss: 0.2098, Test Accuracy: 93.31%
#
# Training with Rotate 180 augmentation - Run 4
# Epoch: 0/15
# Train Loss: 0.4091, Train Accuracy: 78.54%
# Test Loss: 0.2451, Test Accuracy: 90.99%
# Epoch: 1/15
# Train Loss: 0.3646, Train Accuracy: 80.13%
# Test Loss: 0.2299, Test Accuracy: 91.28%
# Epoch: 2/15
# Train Loss: 0.3473, Train Accuracy: 80.96%
# Test Loss: 0.2549, Test Accuracy: 89.23%
# Epoch: 3/15
# Train Loss: 0.3371, Train Accuracy: 81.56%
# Test Loss: 0.2117, Test Accuracy: 91.04%
# Epoch: 4/15
# Train Loss: 0.3316, Train Accuracy: 81.82%
# Test Loss: 0.2095, Test Accuracy: 92.36%
# Epoch: 5/15
# Train Loss: 0.3197, Train Accuracy: 82.12%
# Test Loss: 0.2687, Test Accuracy: 87.09%
# Epoch: 6/15
# Train Loss: 0.3128, Train Accuracy: 82.42%
# Test Loss: 0.2104, Test Accuracy: 92.89%
# Epoch: 7/15
# Train Loss: 0.3041, Train Accuracy: 82.87%
# Test Loss: 0.2252, Test Accuracy: 90.44%
# Epoch: 8/15
# Train Loss: 0.2992, Train Accuracy: 83.10%
# Test Loss: 0.2029, Test Accuracy: 93.03%
# Epoch: 9/15
# Train Loss: 0.2939, Train Accuracy: 83.22%
# Test Loss: 0.1879, Test Accuracy: 92.79%
# Epoch: 10/15
# Train Loss: 0.2846, Train Accuracy: 83.24%
# Test Loss: 0.5119, Test Accuracy: 84.73%
# Epoch: 11/15
# Train Loss: 0.2812, Train Accuracy: 83.50%
# Test Loss: 0.2636, Test Accuracy: 90.45%
# Epoch: 12/15
# Train Loss: 0.2715, Train Accuracy: 84.00%
# Test Loss: 0.2226, Test Accuracy: 92.00%
# Epoch: 13/15
# Train Loss: 0.2738, Train Accuracy: 83.85%
# Test Loss: 0.2357, Test Accuracy: 91.67%
# Epoch 00014: reducing learning rate of group 0 to 5.0000e-04.
# Epoch: 14/15
# Train Loss: 0.2414, Train Accuracy: 84.86%
# Test Loss: 0.2638, Test Accuracy: 91.03%
#
# Training with Rotate 180 augmentation - Run 5
# Epoch: 0/15
# Train Loss: 0.4059, Train Accuracy: 78.57%
# Test Loss: 0.2395, Test Accuracy: 90.96%
# Epoch: 1/15
# Train Loss: 0.3609, Train Accuracy: 80.76%
# Test Loss: 0.2973, Test Accuracy: 87.31%
# Epoch: 2/15
# Train Loss: 0.3475, Train Accuracy: 81.06%
# Test Loss: 0.2180, Test Accuracy: 91.81%
# Epoch: 3/15
# Train Loss: 0.3343, Train Accuracy: 81.63%
# Test Loss: 0.2375, Test Accuracy: 90.63%
# Epoch: 4/15
# Train Loss: 0.3236, Train Accuracy: 82.14%
# Test Loss: 0.2167, Test Accuracy: 92.72%
# Epoch: 5/15
# Train Loss: 0.3186, Train Accuracy: 82.05%
# Test Loss: 0.1947, Test Accuracy: 92.72%
# Epoch: 6/15
# Train Loss: 0.3151, Train Accuracy: 82.16%
# Test Loss: 0.2082, Test Accuracy: 92.72%
# Epoch: 7/15
# Train Loss: 0.3145, Train Accuracy: 82.31%
# Test Loss: 0.2151, Test Accuracy: 91.47%
# Epoch: 8/15
# Train Loss: 0.2990, Train Accuracy: 82.85%
# Test Loss: 0.2451, Test Accuracy: 89.01%
# Epoch: 9/15
# Train Loss: 0.2959, Train Accuracy: 82.88%
# Test Loss: 0.1946, Test Accuracy: 92.64%
# Epoch: 10/15
# Train Loss: 0.2867, Train Accuracy: 83.48%
# Test Loss: 0.1885, Test Accuracy: 93.29%
# Epoch: 11/15
# Train Loss: 0.2845, Train Accuracy: 83.44%
# Test Loss: 0.1905, Test Accuracy: 92.89%
# Epoch: 12/15
# Train Loss: 0.2717, Train Accuracy: 83.93%
# Test Loss: 0.1859, Test Accuracy: 93.44%
# Epoch: 13/15
# Train Loss: 0.2676, Train Accuracy: 84.10%
# Test Loss: 0.2236, Test Accuracy: 92.27%
# Epoch: 14/15
# Train Loss: 0.2621, Train Accuracy: 84.34%
# Test Loss: 0.2076, Test Accuracy: 92.63%
