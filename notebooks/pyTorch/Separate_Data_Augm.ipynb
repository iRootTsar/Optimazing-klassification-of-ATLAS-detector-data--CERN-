# %% [markdown]
# Here we try and use VGG net since it has simpler architecture for small dataset which is perfect for our 50x50 pictures
#
# We also try to run training of data augmentaion on separate data augmentation techniques

# %%
import numpy as np
import matplotlib.pyplot as plt
from torchsummary import summary

import sys
from pathlib import Path

#torch 
import torch
import torchvision as torchv
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from torch import Tensor
from torch.utils import data
from PIL import Image
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_fscore_support

import pandas as pd
import seaborn as sn

# %%
#Metode for å hente data frå mappe
module_path = str(Path.cwd().parents[0].parents[0] / "methods")

if module_path not in sys.path:
    sys.path.append(module_path)

from dataloader import *
# from plotCreator import *

data_path0 = str(Path.cwd().parents[0].parents[0] / "data" / "BH_n4_M10_res50_15000_events.h5")
data_path1 = str(Path.cwd().parents[0].parents[0] / "data" / "PP13-Sphaleron-THR9-FRZ15-NB0-NSUBPALL_res50_15000_events.h5")

# %%
#Hente data og sette til array
bhArray = dataToArray(data_path0)
sphArray = dataToArray(data_path1)

# %%
#Kombinerer dataene for å kunne kjøre gjennom modellen på et samlet datasett
dataArray = np.concatenate((bhArray,sphArray),axis=0)

# %%
# Label array where BH is 0 and Sphalerons are 1
labelsArray = np.concatenate((np.zeros(np.shape(bhArray)[0]),np.ones(np.shape(sphArray)[0])),axis=0)

# %%
#Check if device is running on GPU
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("Running on the GPU")
else:
    device = torch.device("cpu")
    print("Running on the CPU")
# Out:
# Running on the GPU

# %%
#Split data 75% into train and 25% into test
trainData, testData, trainLabels, testLabels = train_test_split(dataArray, labelsArray, random_state=42)

# %% [markdown]
# Data augmentation process where we flip horizontally, and rotate images by 180 degrees randomly thus increasing training set.
# As well as we siplace images top down on y axes
#
# Commented out part where we crop images in width which can potentially increase models precision

# %%
def random_shift_y(img, roll_axis):
    shift = torch.randint(low=0, high=list(img.shape)[roll_axis], size=(1, 1)).item()
    img = torch.roll(img, shift, roll_axis)
    return img

def augment_images(images):
    images = np.moveaxis(images, -1, 1)
    augmented_images = []
    for img in images:
        img = torch.from_numpy(img)
        
        img_flipped_horizontal = torch.flip(img, dims=[2])
        img_flipped_vertical = random_shift_y(img, roll_axis=1)
        img_rotated_180 = torch.rot90(img, 2, dims=[1, 2])

        augmented_images.extend(
            [img, img_flipped_horizontal, img_flipped_vertical, img_rotated_180]
        )
    return torch.stack(augmented_images)  # Use torch.stack instead of np.array

# Apply data augmentation only on the training set
augmented_trainData = augment_images(trainData)

# Repeat the labels for the training set to match the augmented dataset
trainLabels_repeated = np.repeat(trainLabels, 4)

# Convert the augmented training data and repeated labels to PyTorch tensors
trainLabels_repeated = torch.from_numpy(trainLabels_repeated)

# Create a TensorDataset from the augmented training data and repeated labels
train_augmented = torch.utils.data.TensorDataset(augmented_trainData, trainLabels_repeated)

# Create a DataLoader for the augmented training dataset with shuffle enabled and batch size of 50
trainLoader_augmented = DataLoader(train_augmented, shuffle=True, batch_size=50)

# Apply the same preprocessing step to the test set as the training set
testData_processed = np.moveaxis(testData, -1, 1)

# Create a TensorDataset for the test data
test = torch.utils.data.TensorDataset(torch.from_numpy(testData_processed), torch.from_numpy(testLabels))

# Create a DataLoader for the test data with shuffle and batch size
testLoader = DataLoader(test, shuffle=True, batch_size=50)

# %% [markdown]
# This code allows us to look on orignial data image as well as its augmented forms

# %%
def visualize_comparison(original_images, augmented_images, labels, title, augmentation_info=None):
    n_images = len(original_images)
    n_columns = 4
    n_rows = n_images

    augmented_types = ['Original', 'Flip Vertical', 'Displace up/down', 'Rotate 180']

    fig, axs = plt.subplots(n_rows, n_columns, figsize=(3 * n_columns, 3 * n_rows))
    fig.suptitle(title)

    for i in range(n_images):
        for j in range(n_columns):
            if j == 0:
                img = original_images[i]
            else:
                img = augmented_images[4 * i + j]

            if isinstance(img, np.ndarray):
                img_rgb = np.moveaxis(img, 0, -1) if img.shape[0] == 3 else img
            elif isinstance(img, torch.Tensor):
                img_rgb = np.moveaxis(img.numpy(), 0, -1)

            ax = axs[i, j]
            ax.imshow(img_rgb)
            ax.set_title(f"{augmented_types[j]} - Label: {'BH' if labels[i] == 1 else 'SPH'}") #Change labels such that if 1 Bh if 1 then Sph
            ax.axis('off')

    plt.show()

n_samples = 4
original_images = trainData[:n_samples]
original_labels = trainLabels[:n_samples]
augmented_images = augmented_trainData[:4 * n_samples]

visualize_comparison(original_images, augmented_images, original_labels, title="Original and Augmented Images")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# Here we make a call on nnmodel.py in methods fodler where all our models resign

# %%
import nnmodel

model = nnmodel.VGGNet2(0.5).to(device)  # Move the model to the appropriate device

# Print the model summary, make sure to provide appropriate input size (3, 50, 50) for the 3-channel 50x50 images
summary(model, (3, 50, 50))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 50, 50]           1,792
#        BatchNorm2d-2           [-1, 64, 50, 50]             128
#               ReLU-3           [-1, 64, 50, 50]               0
#             Conv2d-4           [-1, 64, 50, 50]          36,928
#        BatchNorm2d-5           [-1, 64, 50, 50]             128
#               ReLU-6           [-1, 64, 50, 50]               0
#          MaxPool2d-7           [-1, 64, 25, 25]               0
#            Dropout-8           [-1, 64, 25, 25]               0
#             Conv2d-9          [-1, 128, 25, 25]          73,856
#       BatchNorm2d-10          [-1, 128, 25, 25]             256
#              ReLU-11          [-1, 128, 25, 25]               0
#            Conv2d-12          [-1, 128, 25, 25]         147,584
#       BatchNorm2d-13          [-1, 128, 25, 25]             256
#              ReLU-14          [-1, 128, 25, 25]               0
#            Conv2d-15          [-1, 128, 25, 25]         147,584
#       BatchNorm2d-16          [-1, 128, 25, 25]             256
#              ReLU-17          [-1, 128, 25, 25]               0
#         MaxPool2d-18          [-1, 128, 12, 12]               0
#           Dropout-19          [-1, 128, 12, 12]               0
#            Conv2d-20          [-1, 256, 12, 12]         295,168
#       BatchNorm2d-21          [-1, 256, 12, 12]             512
#              ReLU-22          [-1, 256, 12, 12]               0
#            Conv2d-23          [-1, 256, 12, 12]         590,080
#       BatchNorm2d-24          [-1, 256, 12, 12]             512
#              ReLU-25          [-1, 256, 12, 12]               0
#            Conv2d-26          [-1, 256, 12, 12]         590,080
#       BatchNorm2d-27          [-1, 256, 12, 12]             512
#              ReLU-28          [-1, 256, 12, 12]               0
#         MaxPool2d-29            [-1, 256, 6, 6]               0
#           Dropout-30            [-1, 256, 6, 6]               0
#            Conv2d-31            [-1, 512, 6, 6]       1,180,160
#       BatchNorm2d-32            [-1, 512, 6, 6]           1,024
#              ReLU-33            [-1, 512, 6, 6]               0
#            Conv2d-34            [-1, 512, 6, 6]       2,359,808
#       BatchNorm2d-35            [-1, 512, 6, 6]           1,024
#              ReLU-36            [-1, 512, 6, 6]               0
#            Conv2d-37            [-1, 512, 6, 6]       2,359,808
#       BatchNorm2d-38            [-1, 512, 6, 6]           1,024
#              ReLU-39            [-1, 512, 6, 6]               0
#         MaxPool2d-40            [-1, 512, 3, 3]               0
#           Dropout-41            [-1, 512, 3, 3]               0
#            Conv2d-42           [-1, 64, 50, 50]           1,792
#       BatchNorm2d-43           [-1, 64, 50, 50]             128
#              ReLU-44           [-1, 64, 50, 50]               0
#            Conv2d-45           [-1, 64, 50, 50]          36,928
#       BatchNorm2d-46           [-1, 64, 50, 50]             128
#              ReLU-47           [-1, 64, 50, 50]               0
#         MaxPool2d-48           [-1, 64, 25, 25]               0
#           Dropout-49           [-1, 64, 25, 25]               0
#            Conv2d-50          [-1, 128, 25, 25]          73,856
#       BatchNorm2d-51          [-1, 128, 25, 25]             256
#              ReLU-52          [-1, 128, 25, 25]               0
#            Conv2d-53          [-1, 128, 25, 25]         147,584
#       BatchNorm2d
#           Conv2d-119            [-1, 512, 6, 6]       2,359,808
#      BatchNorm2d-120            [-1, 512, 6, 6]           1,024
#             ReLU-121            [-1, 512, 6, 6]               0
#        MaxPool2d-122            [-1, 512, 3, 3]               0
#          Dropout-123            [-1, 512, 3, 3]               0
#           Conv2d-124           [-1, 64, 50, 50]           1,792
#      BatchNorm2d-125           [-1, 64, 50, 50]             128
#             ReLU-126           [-1, 64, 50, 50]               0
#           Conv2d-127           [-1, 64, 50, 50]          36,928
#      BatchNorm2d-128           [-1, 64, 50, 50]             128
#             ReLU-129           [-1, 64, 50, 50]               0
#        MaxPool2d-130           [-1, 64, 25, 25]               0
#          Dropout-131           [-1, 64, 25, 25]               0
#           Conv2d-132          [-1, 128, 25, 25]          73,856
#      BatchNorm2d-133          [-1, 128, 25, 25]             256
#             ReLU-134          [-1, 128, 25, 25]               0
#           Conv2d-135          [-1, 128, 25, 25]         147,584
#      BatchNorm2d-136          [-1, 128, 25, 25]             256
#             ReLU-137          [-1, 128, 25, 25]               0
#           Conv2d-138          [-1, 128, 25, 25]         147,584
#      BatchNorm2d-139          [-1, 128, 25, 25]             256
#             ReLU-140          [-1, 128, 25, 25]               0
#        MaxPool2d-141          [-1, 128, 12, 12]               0
#          Dropout-142          [-1, 128, 12, 12]               0
#           Conv2d-143          [-1, 256, 12, 12]         295,168
#      BatchNorm2d-144          [-1, 256, 12, 12]             512
#             ReLU-145          [-1, 256, 12, 12]               0
#           Conv2d-146          [-1, 256, 12, 12]         590,080
#      BatchNorm2d-147          [-1, 256, 12, 12]             512
#             ReLU-148          [-1, 256, 12, 12]               0
#           Conv2d-149          [-1, 256, 12, 12]         590,080
#      BatchNorm2d-150          [-1, 256, 12, 12]             512
#             ReLU-151          [-1, 256, 12, 12]               0
#        MaxPool2d-152            [-1, 256, 6, 6]               0
#          Dropout-153            [-1, 256, 6, 6]               0
#           Conv2d-154            [-1, 512, 6, 6]       1,180,160
#      BatchNorm2d-155            [-1, 512, 6, 6]           1,024
#             ReLU-156            [-1, 512, 6, 6]               0
#           Conv2d-157            [-1, 512, 6, 6]       2,359,808
#      BatchNorm2d-158            [-1, 512, 6, 6]           1,024
#             ReLU-159            [-1, 512, 6, 6]               0
#           Conv2d-160            [-1, 512, 6, 6]       2,359,808
#      BatchNorm2d-161            [-1, 512, 6, 6]           1,024
#             ReLU-162            [-1, 512, 6, 6]               0
#        MaxPool2d-163            [-1, 512, 3, 3]               0
#          Dropout-164            [-1, 512, 3, 3]               0
#           Linear-165                 [-1, 1024]       4,719,616
#             ReLU-166                 [-1, 1024]               0
#          Dropout-167                 [-1, 1024]               0
#           Linear-168                  [-1, 512]         524,800
#             ReLU-169                  [-1, 512]               0
#          Dropout-170                  [-1, 512]               0
#           Linear-171                  [-1, 256]         131,328
#             ReLU-172                  [-1, 256]               0
#          Dropout-173                  [-1, 256]               0
#           Linear-174                    [-1, 2]             514
# ================================================================
# Total params: 36,530,178
# Trainable params: 36,530,178
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.03
# Forward/backward pass size (MB): 70.91
# Params size (MB): 139.35
# Estimated Total Size (MB): 210.29
# ----------------------------------------------------------------

# %% [markdown]
# This function allow us to plot all metrics

# %%
def plot_metrics(augmentation_types, all_metrics):
    num_types = len(augmentation_types)

    plt.figure(figsize=(20, 20))
    
    plot_index = 1
    for metric_name in all_metrics[0].keys():
        plt.subplot(4, 4, plot_index)
        for i, augment_type in enumerate(augmentation_types):
            plt.plot(all_metrics[i][metric_name], label=f'{augment_type} {metric_name}')
        plt.legend()
        plt.xlabel('Epoch')
        plt.ylabel(metric_name)
        plt.title(f'{metric_name} with Different Augmentations')
        plot_index += 1

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Here we make a call on train method from methods folder file trainers.py where all training and testing happends as well as plotting of accuracy, loss, precision, recall etc.
#
# Few changes added scheduler and early stopping to prevent from overfitting with changing learning rate if test loss and accuracy doesnt improve.

# %% [markdown]
# Here we train data and get plot of different augmentation techniques

# %%
import trainerDataAug

def train_with_augmentations(augmentation_types):
    all_metrics = []
    for augment_type in augmentation_types:
        print(f"\nTraining with {augment_type} augmentation")

        # Filter the augmented training data based on the augmentation type
        filter_indices = list(range(0, len(augmented_trainData), 4))  # Original images are always included
        if augment_type != "None":
            aug_type_index = augmentation_types.index(augment_type)
            filter_indices += list(range(aug_type_index + 1, len(augmented_trainData), 4))
        filtered_trainData = augmented_trainData[filter_indices]
        filtered_trainLabels = trainLabels_repeated[filter_indices]

        # Create a TensorDataset and DataLoader for the filtered training data
        train_filtered = torch.utils.data.TensorDataset(filtered_trainData, filtered_trainLabels)
        trainLoader_filtered = DataLoader(train_filtered, shuffle=True, batch_size=50)

        # Train the model with the filtered training data
        model = nnmodel.VGGNet2(0.5).to(device)
        optimizer = torch.optim.Adam(model.parameters())
        criterion = nn.CrossEntropyLoss().to(device)
        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=3, verbose=True, factor=0.5)
        metrics = trainerDataAug.train(model, trainLoader_filtered, testLoader, optimizer, criterion, n_epochs=20, scheduler = scheduler, early_stopping_patience=10)

        all_metrics.append(metrics)
    
    plot_metrics(augmentation_types, all_metrics)
# Train and compare the model with different data augmentations
augmentation_types = ["None", "Flip Horizontal", "Random Shift Y", "Rotate 180"]
train_with_augmentations(augmentation_types)
# Out:
# Training with None augmentation
# Epoch: 0/20
# Train Loss: 0.3343, Train Accuracy: 86.85%
# Test Loss: 0.3244, Test Accuracy: 86.64%
# Epoch: 1/20
# Train Loss: 0.2500, Train Accuracy: 90.71%
# Test Loss: 0.1946, Test Accuracy: 92.52%
# Epoch: 2/20
# Train Loss: 0.2306, Train Accuracy: 91.31%
# Test Loss: 0.2106, Test Accuracy: 92.00%
# Epoch: 3/20
# Train Loss: 0.2186, Train Accuracy: 91.82%
# Test Loss: 0.2283, Test Accuracy: 90.39%
# Epoch: 4/20
# Train Loss: 0.2101, Train Accuracy: 92.11%
# Test Loss: 0.2063, Test Accuracy: 91.00%
# Epoch: 5/20
# Train Loss: 0.2021, Train Accuracy: 92.60%
# Test Loss: 0.1962, Test Accuracy: 92.39%
# Epoch 00006: reducing learning rate of group 0 to 5.0000e-04.
# Epoch: 6/20
# Train Loss: 0.1894, Train Accuracy: 93.00%
# Test Loss: 0.1821, Test Accuracy: 93.72%
# Epoch: 7/20
# Train Loss: 0.1832, Train Accuracy: 93.10%
# Test Loss: 0.1754, Test Accuracy: 93.65%
# Epoch: 8/20
# Train Loss: 0.1757, Train Accuracy: 93.35%
# Test Loss: 0.1941, Test Accuracy: 92.72%
# Epoch: 9/20
# Train Loss: 0.1770, Train Accuracy: 93.49%
# Test Loss: 0.1889, Test Accuracy: 92.29%
# Epoch: 10/20
# Train Loss: 0.1759, Train Accuracy: 93.40%
# Test Loss: 0.2668, Test Accuracy: 88.57%
# Epoch: 11/20
# Train Loss: 0.1699, Train Accuracy: 93.53%
# Test Loss: 0.1845, Test Accuracy: 93.15%
# Epoch 00012: reducing learning rate of group 0 to 2.5000e-04.
# Epo
# Epoch 00020: reducing learning rate of group 0 to 1.2500e-04.
#
# Training with Rotate 180 augmentation
# Epoch: 0/20
# Train Loss: 0.2784, Train Accuracy: 89.30%
# Test Loss: 0.2631, Test Accuracy: 88.97%
# Epoch: 1/20
# Train Loss: 0.2266, Train Accuracy: 91.63%
# Test Loss: 0.2411, Test Accuracy: 90.07%
# Epoch: 2/20
# Train Loss: 0.2121, Train Accuracy: 92.18%
# Test Loss: 0.1925, Test Accuracy: 92.75%
# Epoch: 3/20
# Train Loss: 0.2015, Train Accuracy: 92.56%
# Test Loss: 0.2013, Test Accuracy: 92.92%
# Epoch: 4/20
# Train Loss: 0.1930, Train Accuracy: 92.92%
# Test Loss: 0.2201, Test Accuracy: 90.87%
# Epoch: 5/20
# Train Loss: 0.1866, Train Accuracy: 93.13%
# Test Loss: 0.2010, Test Accuracy: 92.49%
# Epoch: 6/20
# Train Loss: 0.1760, Train Accuracy: 93.41%
# Test Loss: 0.1743, Test Accuracy: 93.71%
# Epoch: 7/20
# Train Loss: 0.1743, Train Accuracy: 93.60%
# Test Loss: 0.1898, Test Accuracy: 93.08%
# Epoch: 8/20
# Train Loss: 0.1678, Train Accuracy: 93.82%
# Test Loss: 0.1845, Test Accuracy: 92.93%
# Epoch: 9/20
# Train Loss: 0.1623, Train Accuracy: 93.99%
# Test Loss: 0.1810, Test Accuracy: 93.16%
# Epoch: 10/20
# Train Loss: 0.1612, Train Accuracy: 94.02%
# Test Loss: 0.1888, Test Accuracy: 92.28%
# Epoch 00011: reducing learning rate of group 0 to 5.0000e-04.
# Epoch: 11/20
# Train Loss: 0.1467, Train Accuracy: 94.58%
# Test Loss: 0.1671, Test Accuracy: 93.45%
# Epoch: 12/20
# Train Loss: 0.1431, Train Accuracy: 94.71%
# Test Loss: 0.1970, Test Accuracy: 91.96%
# Epoch: 13/20
# Train Loss: 0.1417, Train Accuracy: 94.70%
# Test Loss: 0.1513, Test Accuracy: 94.72%
# Epoch: 14/20
# Train Loss: 0.1396, Train Accuracy: 94.71%
# Test Loss: 0.1667, Test Accuracy: 93.35%
# Epoch: 15/20
# Train Loss: 0.1354, Train Accuracy: 94.93%
# Test Loss: 0.1649, Test Accuracy: 93.48%
# Epoch: 16/20
# Train Loss: 0.1336, Train Accuracy: 95.06%
# Test Loss: 0.1525, Test Accuracy: 94.25%
# Epoch: 17/20
# Train Loss: 0.1349, Train Accuracy: 95.01%
# Test Loss: 0.3431, Test Accuracy: 87.49%
# Epoch 00018: reducing learning rate of group 0 to 2.5000e-04.
# Epoch: 18/20
# Train Loss: 0.1243, Train Accuracy: 95.46%
# Test Loss: 0.1809, Test Accuracy: 93.17%
# Epoch: 19/20
# Train Loss: 0.1231, Train Accuracy: 95.43%
# Test Loss: 0.1524, Test Accuracy: 94.29%

# %% [markdown]
# Code below makes it possible to save model

# %%
# #save model
# torch.save(model.state_dict(), model_save_path)

# # Load the saved model
# model.load_state_dict(torch.load(model_save_path))

# # Set the model to evaluation mode
# model.eval()

# # Function to test the model
# def test_model(model, test_loader, device):
#     correct = 0
#     total = 0

#     with torch.no_grad():
#         for data, target in test_loader:
#             data, target = data.to(device), target.to(device)
#             output = model(data)
#             _, predicted = torch.max(output.data, 1)
#             total += target.size(0)
#             correct += (predicted == target).sum().item()

#     accuracy = 100 * correct / total
#     print(f"Accuracy of the model on test data: {accuracy}%")

# # Test the model
# test_model(model, testLoader, device)
